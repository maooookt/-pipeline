# %%
import pandas as pd

# %%
file_path = ''
kind = ['G','A','V','L','I','C','M','S','T','D','E','N','Q','R',
                'K','H','F','Y','W','P','dA','dV','dL','dI','dC','dM',
                'dS','dT','dD','dE','dN','dQ','dR','dK','dH','dF','dY','dW','dP',
               'Abu','Sar','Me_Bmt(E)','meL','meV','meA','meI','meM','meS','meT',
                'meD','meN','meQ','meK','meH','meF','meY','meW']

# %%
csv_file = pd.read_csv('file_path')
acid_list = csv_file[['Sequence','Detection_Limit_1','Detection_Limit_2']]

for row in acid_list.itertuples(index=False):
    seq = ast.literal_eval(row.Sequence)
    de1 = ast.literal_eval(row.Detection_Limit_1)
    de2 = ast.literal_eval(row.Detection_Limit_2)

# %%
import numpy as np

# %%
import sys, os
sys.path.append(os.pardir)
from dataset.mnist import load_mnist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 3
#       1 import sys, os
#       2 sys.path.append(os.pardir)
# ----> 3 from dataset.mnist import load_mnist
#
# ModuleNotFoundError: No module named 'dataset'

# %%
os.pardir
# Out:
# '..'

# %%
a = ['a']
print(a)
# Out:
# ['a']

# %%
a = 5
list(range(a))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(1,5))
# Out:
# [1, 2, 3, 4]

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
import numpy as np

# %%
x = np.array([[2,4,5],[6,6,7]])
x
# Out:
# array([[2, 4, 5],
#        [6, 6, 7]])

# %%
len(x)
# Out:
# 2

# %%
x[0:1]
# Out:
# array([[2, 4, 5]])
