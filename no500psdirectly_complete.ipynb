# %%
pip install biopython
# Out:
# Requirement already satisfied: biopython in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (1.84)
# Requirement already satisfied: numpy in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from biopython) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ### CSVの配列Sar⇨meG

# %%
#csvに含まれる配列にSaRがあったらmeGに変えるコード
import os
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

# テキストボックスの作成
array_input = widgets.Text(
    value='',
    placeholder='表のディレクトリパスを入力してください',
    description='パス:',
)

# ボタンの作成
run_button = widgets.Button(
    description='実行',
    button_style='success'
)

# 出力エリアの作成
output_area = widgets.Output()

# テキストボックスとボタン、出力エリアの表示
display(array_input, run_button, output_area)

# 実行ボタンが押されたときに呼び出される関数
def on_button_click(b):
    output_area.clear_output()  # 出力エリアをクリア
    with output_area:
        try:
            file_path = array_input.value  # テキストボックスの入力を取得
            
            # ファイルが存在するかチェック
            if not os.path.exists(file_path):
                raise FileNotFoundError(f"File not found: {file_path}")
            
            # CSVファイルの読み込み
            df = pd.read_csv(file_path)
            
            # "SAR" を "meG" に置き換え
            if "SAR" in df['Sequence'].values:
                df.loc[df['Sequence'] == "SAR", 'Sequence'] = "meG"
            
            # CSVファイルの保存
            df.to_csv(file_path, index=False)
            print(f"Updated CSV file saved: {file_path}")
        
        except FileNotFoundError as e:
            print(f"File not found: {e}")
        except pd.errors.EmptyDataError:
            print("The CSV file is empty.")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# ボタンがクリックされたときに関数を呼び出す
run_button.on_click(on_button_click)
# Out:
# Text(value='', description='パス:', placeholder='表のディレクトリパスを入力してください')
# Button(button_style='success', description='実行', style=ButtonStyle())
# Output()

# %% [markdown]
# ### 直接入力で実行

# %%
import subprocess
import os
import paramiko
import ipywidgets as widgets
from IPython.display import display

# テキストボックスの作成
array_input = widgets.Text(
    value='',
    placeholder='配列を入力してください',
    description='配列:',
)

# ボタンの作成
run_button = widgets.Button(
    description='実行',
    button_style='success'
)

# 出力エリアの作成
output_area = widgets.Output()

# テキストボックスとボタン、出力エリアの表示
display(array_input, run_button, output_area)

# 実行ボタンが押されたときに呼び出される関数
def on_button_click(b):
    global input_list  # 必要であればグローバル変数として宣言
    global value
    with output_area:
        output_area.clear_output()
        input_text = array_input.value  # テキストボックスから現在の入力を取得
        value = input_text
        input_list = input_text.split(',')  # カンマで分割してリスト化
        print(f'入力された値: {value}')
        print(f'リスト化：{input_list}')
        
        # 必要な変数をここで定義
        segid = "PROA"
        rename_str = "rename_str_example"
        delete_str = "delete_str_example"
        cycpep = "cycpep_example"
        try:
            copy_seed_work(value)
        except NameError:
            print('Error: copy_seed_work 関数が定義されていません。')
        except Exception as e:
            print(f'An error occurred in copy_seed_work: {e}')
        try:
            copy_seed_pdb(value, input_list)
        except NameError:
            print('Error: copy_seed_pdb 関数が定義されていません。')
        except Exception as e:
            print(f'An error occurred in copy_seed_pdb: {e}')

        try:
            rename_pdb_atom(input_list)
        except NameError:
            print('Error: rename_pdb_atom 関数が定義されていません。')
        except Exception as e:
            print(f'An error occurred in rename_pdb_atom: {e}')

        try:
            make_rename_tcl(input_list, value)
        except NameError:
            print('Error: make_rename_tcl 関数が定義されていません。')
        except Exception as e:
            print(f'An error occurred in make_rename_tcl: {e}')
                
        try:
            seed_charmm(input_list)
        except NameError:
            print("Error: seed_charmm 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in seed_charmm: {e}")

        try:
            in_charminp(value)
        except NameError:
            print("Error: in_charminp 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in in_charminp: {e}")

        try:
            gbsw_in_charmm(input_list)
        except NameError:
            print("Error: gbsw_in_charmm 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in gbsw_in_charmm: {e}")
                
        try:
            gbsw_sur_charmm(input_list)
        except NameError:
            print("Error: gbsw_sur_charmm 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in gbsw_sur_charmm: {e}")

        try:
            gbsw_out_charmm(input_list)
        except NameError:
            print("Error: gbsw_out_charmm 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in gbsw_out_charmm: {e}")

        try:
            in_gbsw_in(value)
        except NameError:
            print("Error: in_gbsw_in 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in in_gbsw_in: {e}")

        try:
            in_gbsw_sur(value)
        except NameError:
            print("Error: in_gbsw_sur 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in in_gbsw_sur: {e}")

        try:
            in_gbsw_out(value)
        except NameError:
            print("Error: in_gbsw_out 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in in_gbsw_out: {e}")
        
        try:
            connect_server()
        except NameError:
            print("Error: connect_server 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in connect_server: {e}")

        try:
            send_dir(value)
        except NameError:
            print("Error: send_dir 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in send_dir: {e}")
        
        try:
            run_sh_gbsw(value)
        except NameError:
            print("Error: run_sh_gbsw 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in run_sh_gbsw: {e}")

        try:
            run_sh_hbond(value)
        except NameError:
            print("Error: run_sh_gbsw 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in run_sh_hbond: {e}")
        try:
            run_sh_surf(value)
        except NameError:
            print("Error: run_sh_surf 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in run_sh_surf: {e}")
                    
        try:
            return_copy_work(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in return_copy_work: {e}")
                    
        try:
            summarize_solv_free_ene(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in summarize_solv_free_ene: {e}")
                    
        try:
            summarize_van_der_ener(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in summarize_van_der_ener: {e}")
                    
        try:
            summarize_coul_ener(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in summarize_coul_ener: {e}")
    
        try:
            calculate_column_average(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in calculate_column_average: {e}")
                
        try:
            calculate_hbond_average(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in calculate_hbond_average: {e}")
        try:
            calculate_surf_average(value)
        except NameError:
            print("Error: calculate_surf_average 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in calculate_surf_average: {e}")
    
        try:
            save_results(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in save_results: {e}")
    
        #try:
        #    in_csv(file_path)
        #except NameError:
        #    print("Error: return_copy_work 関数が定義されていません。")
        #except Exception as e:
        #    print(f"An error occurred in in_csv: {e}")
                
        try:
            update_csv_in(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in update_csv_in: {e}")
                
        try:
            update_csv_sur(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in update_csv_sur: {e}")
                
        try:
            update_csv_out(value)
        except NameError:
            print("Error: return_copy_work 関数が定義されていません。")
        except Exception as e:
            print(f"An error occurred in update_csv_out: {e}")


        

                
# ボタンがクリックされたときに実行されるように設定
run_button.on_click(on_button_click)
# Out:
# Text(value='', description='配列:', placeholder='配列を入力してください')
# Button(button_style='success', description='実行', style=ButtonStyle())
# Output()

# %% [markdown]
# ### seed_workからコピーする

# %%
def copy_seed_work(value):
    # コピー元とコピー先のパスを定義
    source_path = "/Users/teraimao/experiment/work/seed_work"
    destination_path = f"/Users/teraimao/experiment/work/{value}_work"
    
    # ディレクトリが存在するか確認
    import os
    if not os.path.exists(source_path):
        print(f"Error: The source directory '{source_path}' does not exist.")
        return
    
    # コピーコマンドの実行
    #subprocess.run(["cp", "-r", source_path, destination_path], check=True)
    try:
        subprocess.run(["cp", "-r", source_path, destination_path], check=True)
        print(f"Directory copied successfully to '{destination_path}'.")
    except subprocess.CalledProcessError as e:
        print(f"Error occurred during copying: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %% [markdown]
# ### 配列数に合わせてpdbコピー

# %%
#配列を入力すると配列名に合わせてMD計算に使うディレクトリをコピーしてくれるコマンド
import subprocess
import os

def copy_seed_pdb(value, input_list):
    destination_path = f"/Users/teraimao/experiment/work/{value}_work/"
    
    try:
        # 配列の長さに応じてコピーするファイルを選択
        if len(input_list) == 4:
            source_path = "/Users/teraimao/experiment/data/seed_pdb/gl4.pdb"
        elif len(input_list) == 5:
            source_path = "/Users/teraimao/experiment/data/seed_pdb/gl5.pdb"
        elif len(input_list) == 6:
            source_path = "/Users/teraimao/experiment/data/seed_pdb/gl6.pdb"
        elif len(input_list) == 11:
            source_path = "/Users/teraimao/experiment/data/seed_pdb/gl11.pdb"
        else:
            print("Error: 対応するファイルがありません。")
            return
        
        # ファイルが存在するか確認
        if not os.path.exists(source_path):
            print(f"Error: The source file '{source_path}' does not exist.")
            return
        
        # ファイルをコピー
        subprocess.run(["cp", source_path, destination_path], check=True)
        print(f"'{source_path}' was copied successfully to '{destination_path}'.")
        
    except subprocess.CalledProcessError as e:
        print(f"Error occurred while copying the file: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %% [markdown]
# ### アミノ酸名変更のbuild.tcl作成

# %%
#pdbファイルのアミノ酸名を変えるbuild.tclファイルの作成

def rename_pdb_atom(input_list):
    kind = {'G':'GLY','A':'ALA','V':'VAL','L':'LEU','I':'ILE','C':'CYS',
            'M':'MET','S':'SER','T':'THR','D':'ASP','E':'GLU','N':'ASN','Q':'GLN','R':'ARG',
            'K':'LYS','H':'HIS','F':'PHE','Y':'TYR','W':'TRP','P':'PRO',
            'dA':'DAL','dV':'DVL','dL':'DLU','dI':'DIL','dC':'DCY','dM':'DME',
            'dS':'DSE','dT':'DTH','dD':'DSP','dE':'DGU','dN':'DAS','dQ':'DGL',
            'dR':'DA','dK':'DLS','dH':'DHS','dF':'DPE','dY':'DTY','dW':'DTP','dP':'DPR',
            'ABA':'ABA','SAR':'SAR','BMT':'BMT','meL':'LEU','meV':'VAL','meA':'ALA',
            'meI':'ILE','meM':'MET','meS':'SER','meT':'THR','meD':'ASP','meN':'ASN',
            'meQ':'GLN','meK':'LYS','meH':'HIS','meF':'PHE','meY':'TYR','meW':'TRP'}
    rename_command = []
    for i,atom_name in enumerate(input_list):
        atom = kind.get(atom_name)
        if atom:
            rename = f'[atomselect top "resname GLY and resid {i+1}"] set resname {atom}'
            rename_command.append(rename)
    
    rename_str = "\n".join(rename_command)
    
    if len(input_list) == 4:
        gly = 'gl4'
    elif len(input_list) == 5:
        gly = 'gl5'
    elif len(input_list) == 6:
        gly = 'gly6'
    elif len(input_list) == 11:
        gly = 'gl11'
    #build.tclファイルの作成
    build_script = f"""
mol load pdb ../{gly}.pdb

{rename_str}

[atomselect top "all"] writepdb proa.pdb
exit
    """
    return build_script

# %% [markdown]
# ### build.tcl実行

# %%
import os
import subprocess

vmd_executable = "/Applications/VMD.app/Contents/vmd/vmd_MACOSXARM64"  # VMDのフルパス

def make_rename_tcl(input_list, value):
    # VMDスクリプト内容を生成
    rename_build_tcl = rename_pdb_atom(input_list)
    
    # 作業ディレクトリとスクリプトの出力先を定義
    working_dir = f"/Users/teraimao/experiment/work/{value}_work/rename"
    destination_path = os.path.join(working_dir, "build.tcl")
    
    # 作業ディレクトリが存在しなければ作成
    if not os.path.exists(working_dir):
        os.makedirs(working_dir)
    
    # build.tclファイルを作成
    with open(destination_path, 'w') as file:
        file.write(rename_build_tcl)
    
    # build.tclファイルが正しく作成されたか確認
    if not os.path.exists(destination_path):
        print(f"Error: {destination_path} が存在しません。ファイルパスを確認してください。")
        return
    
    # VMDの実行
    try:
        log_path = os.path.join(working_dir, "log")
        with open(log_path, "w") as log_file:
            subprocess.run(
                [vmd_executable, "-dispdev", "text", "-e", destination_path],
                stdout=log_file, stderr=subprocess.PIPE, check=True, cwd=working_dir
            )
        print(f"VMD executed successfully, and output saved to '{log_path}'.")
    except subprocess.CalledProcessError as e:
        print(f"Error occurred during VMD execution: {e.stderr}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %% [markdown]
# ### charmm.inp作成

# %%
#charmm.inpの作成
import os

def seed_charmm(input_list):
    segid = "PROA"
    last = len(input_list)
    cycpep = f'patch CYCPEP PROA 1 PROA {last} setup sort warn'

    # NMEパッチコマンドを生成
    nme_patches = "\n".join(
        [f'patch NME PROA {i+1} setup sort warn' for i, res in enumerate(input_list) if 'me' in res]
    )
    bmt_nme_patches = "\n".join(
        [f'patch NME PROA {i+1} setup sort warn' for i, res in enumerate(input_list) if 'BMT' in res]
    )


    # CHARMMスクリプトの生成
    charmm_script = f"""
wrnlev 5
prnlev 5 node 0 

open read card name ../toppar/4.1top_all36_prot.rtf unit 20
read rtf card unit 20
close unit 20

open read card name ../toppar/2_1gbsw_par_all36m_prot.prm unit 10
read parameter card unit 10
close unit 10

open read card name ../rename/proa.pdb unit 21
read sequence pdb unit 21

generate {segid} setup first NONE last NONE
{cycpep}
{nme_patches}
{bmt_nme_patches}
autogen ANGLes DIHEdrals 

rewind unit 21

read coordinate pdb unit 21
close unit 21

# !ic fill preserve
ic parameter
ic build
hbuild sele type H* end

bomb -1

open write card name temp.pdb unit 14
write coordinates pdb select all end unit 14

close unit 14

# !delete atom select all end


cons fix sele segid {segid} .and. (type N .or. type CA .or. type C .or. type O) end
MINI ABNR NSTEP 10000 NPRINT 100
cons fix clear

open unit 40 write form name "peptide.pdb"
write coor pdb unit 40
close unit 40

open unit 50 write form name "peptide.psf"
write psf card unit 50
close unit 50

system "rm temp.pdb"

stop
    """
    
    return charmm_script

# %% [markdown]
# ### gbsw_inのcharmm.inp

# %%
#gbswのcharmm.inpの作成

def gbsw_in_charmm(input_list):
    last = len(input_list)
    cycpep = f'patch CYCPEP PROA 1 PROA {last} setup sort warn'
    
    nme_patches = "\n".join(
        [f'patch NME PROA {i+1} setup sort warn' for i, res in enumerate(input_list) if 'me' in res]
    )
    bmt_nme_patches = "\n".join(
        [f'patch NME PROA {i+1} setup sort warn' for i, res in enumerate(input_list) if 'BMT' in res]
    )
    
    gbsw_script = f"""
! Read rtf and parm
open read card name ../toppar/4.1top_all36_prot.rtf unit 10
read rtf card unit 10
close unit 10

open read card name ../toppar/2_1gbsw_par_all36m_prot.prm unit 10
read parameter card unit 10
close unit 10

open read card name ../charmm/peptide.pdb unit 20
read sequ pdb unit 20
close unit 20

generate PROA setup first NONE last NONE
{cycpep}
{nme_patches}
{bmt_nme_patches}
autogen ANGLes DIHEdrals

open unit 25 write form name "peptide_in.psf"
write psf card unit 25
close unit 25

open read card name peptide_in.psf unit 30
read psf card unit 30
close unit 30

# !read coor
open read card name ../charmm/peptide.pdb unit 20
read coor pdb unit 20
close unit 20

ic para
hbuild

# !read gbsw CMAP parameter
open read card name ../../../data/par_all22_prot_gbsw.inp unit 15
read parameter card unit 15
close unit 15

set temp = 303.15

wrnlev 5
prnlev 0 
stream ../../../data/radii_prot_na.str
stream ../../../data/radius_gbsw.str
stream ../../../data/radius.str
prnlev 5

CONS hmcm Force 100.0 weig refx 0.0 refy 0.0 refz 23.0 sele segid PROA end

scalar wmain statistics select .not. type H* end
define check select ( .not. type H* ) .and. ( property wmain .eq. 0.0 ) show end
if ?nsel ne 0 stop

GBSW SW 0.3 RMAX 20.0 NANG 38 SGAMMA 0.04 TMEMB 30 MSW 2.5 CONC 0.15 TEMP @temp GBENER

NBOND atom switch cdie vdw vswitch ctonnb 12 ctofnb 14 cutnb 18

open read card name ../toppar/4.1top_all36_prot.rtf unit 10
read rtf card unit 10
close unit 10

open read card name ../toppar/2_1par_all36m_prot.prm unit 10
read parameter card unit 10
close unit 10

# !ENERGY

mini abnr nstep 1000 nprint 10 step 0.002 inbfrq 10


energy

NBOND nbxmod 5 atom rdiel shift vatom vdistance vshift -
      cutnb 8.0 ctofnb 7.5 ctonnb 6.5 eps 2.0 e14fac 0.4 wmin 1.5
COOR SURF RPROBE 1.4 SELE all END
SCALAR WMAIN STAT SELE all END
SCALAR WMAIN SET 0 SELE ALL END

COOR SURF RPROBE 1.4 SELE type O* .or. type N* END
SCALAR WMAIN STAT SELE all END
SCALAR WMAIN SET 0 SELE ALL END

COOR SURF RPROBE 1.4 SELE .not. (type O* .or. type N*) END
SCALAR WMAIN STAT SELE all END
SCALAR WMAIN SET 0 SELE ALL END
NBOND atom switch cdie vdw vswitch ctonnb 12 ctofnb 14 cutnb 18

coor hbond select segid PROA end

open write unform name gbsw_in.rst unit 26
open write unform name gbsw_in.dcd unit 26

shake BONH para tol 1.0d-07

scalar fbeta set 3.0 select all end
scalar fbeta set 0.0 select type H* end
DYNA LEAP LANGEVIN start  NSTEP 1000000 TIMEstp 0.0005 NPRINT 2000 -
     INBFRQ 25 TBATH 303.15 FIRSTT 303.15 FINALt 303.15 TSTRUC 303.15 - 
     IHBFrq -1 NSAVcrd 2000 ISEED 12345 IUNCRD 26

SHAKE OFF

mini abnr nstep 1000 nprint 10

close unit 25


stop
    """
    return gbsw_script

# %% [markdown]
# ### gbsw_surのcharmm.inp

# %%
def gbsw_sur_charmm(input_list):
    last = len(input_list)
    cycpep = f'patch CYCPEP PROA 1 PROA {last} setup sort warn'
    nme_patches = "\n".join(
        [f'patch NME PROA {i+1} setup sort warn' for i, res in enumerate(input_list) if 'me' in res]
    )
    bmt_nme_patches = "\n".join(
        [f'patch NME PROA {i+1} setup sort warn' for i, res in enumerate(input_list) if 'BMT' in res]
    )
    
    gbsw_script = f"""
! Read rtf and parm
open read card name ../toppar/4.1top_all36_prot.rtf unit 10
read rtf card unit 10
close unit 10


open read card name ../toppar/2_1gbsw_par_all36m_prot.prm unit 10
read parameter card unit 10
close unit 10

open read card name ../charmm/peptide.pdb unit 20
read sequ pdb unit 20
close unit 20

generate PROA setup first NONE last NONE
{cycpep}
{nme_patches}
{bmt_nme_patches}
autogen ANGLes DIHEdrals

open unit 25 write form name "peptide_sur.psf"
write psf card unit 25
close unit 25

open read card name peptide_sur.psf unit 30
read psf card unit 30
close unit 30

# !read coor
open read card name ../charmm/peptide.pdb unit 20
read coor pdb unit 20
close unit 20

ic para
hbuild

# !read gbsw CMAP parameter
open read card name ../../../data/par_all22_prot_gbsw.inp unit 15
read parameter card unit 15
close unit 15

set temp = 303.15

wrnlev 5
prnlev 0 
stream ../../../data/radii_prot_na.str
stream ../../../data/radius_gbsw.str
stream ../../../data/radius.str
prnlev 5

CONS hmcm Force 100.0 weig refx 0.0 refy 0.0 refz 15.0 sele segid PROA end

scalar wmain statistics select .not. type H* end
define check select ( .not. type H* ) .and. ( property wmain .eq. 0.0 ) show end
if ?nsel ne 0 stop

GBSW SW 0.3 RMAX 20.0 NANG 38 SGAMMA 0.04 TMEMB 30 MSW 2.5 CONC 0.15 TEMP @temp GBENER

NBOND atom switch cdie vdw vswitch ctonnb 12 ctofnb 14 cutnb 18

open read card name ../toppar/4.1top_all36_prot.rtf unit 10
read rtf card unit 10
close unit 10

open read card name ../toppar/2_1par_all36m_prot.prm unit 10
read parameter card unit 10
close unit 10

# !ENERGY

mini abnr nstep 1000 nprint 10 step 0.002 inbfrq 10

energy

NBOND nbxmod 5 atom rdiel shift vatom vdistance vshift -
      cutnb 8.0 ctofnb 7.5 ctonnb 6.5 eps 2.0 e14fac 0.4 wmin 1.5
COOR SURF SELE all END

COOR SURF RPROBE 1.4 SELE all END
SCALAR WMAIN STAT SELE all END
SCALAR WMAIN SET 0 SELE ALL END

COOR SURF RPROBE 1.4 SELE type O* .or. type N* END
SCALAR WMAIN STAT SELE all END
SCALAR WMAIN SET 0 SELE ALL END

COOR SURF RPROBE 1.4 SELE .not. (type O* .or. type N*) END
SCALAR WMAIN STAT SELE all END
SCALAR WMAIN SET 0 SELE ALL END

NBOND atom switch cdie vdw vswitch ctonnb 12 ctofnb 14 cutnb 18

coor hbond select segid PROA end

open write unform name gbsw_sur.rst unit 26
open write unform name gbsw_sur.dcd unit 26

shake BONH para tol 1.0d-07

scalar fbeta set 3.0 select all end
scalar fbeta set 0.0 select type H* end
DYNA LEAP LANGEVIN start  NSTEP 1000000 TIMEstp 0.0005 NPRINT 2000 -
     INBFRQ 25 TBATH 303.15 FIRSTT 303.15 FINALt 303.15 TSTRUC 303.15 - 
     IHBFrq -1 NSAVcrd 2000 ISEED 12345 IUNCRD 26

SHAKE OFF

mini abnr nstep 1000 nprint 10

close unit 25


stop
    """
    return gbsw_script

# %% [markdown]
# ### gbsw_outのcharmm.inp

# %%
def gbsw_out_charmm(input_list):
    last = len(input_list)
    cycpep = f'patch CYCPEP PROA 1 PROA {last} setup sort warn'
    nme_patches = "\n".join(
        [f'patch NME PROA {i+1} setup sort warn' for i, res in enumerate(input_list) if 'me' in res]
    )
    bmt_nme_patches = "\n".join(
        [f'patch NME PROA {i+1} setup sort warn' for i, res in enumerate(input_list) if 'BMT' in res]
    )
    
    gbsw_script = f"""

! Read rtf and parm
open read card name ../toppar/4.1top_all36_prot.rtf unit 10
read rtf card unit 10
close unit 10

open read card name ../toppar/2_1gbsw_par_all36m_prot.prm unit 10
read parameter card unit 10
close unit 10

open read card name ../charmm/peptide.pdb unit 20
read sequ pdb unit 20
close unit 20

generate PROA setup first NONE last NONE
{cycpep}
{nme_patches}
{bmt_nme_patches}
autogen ANGLes DIHEdrals

open unit 25 write form name "peptide_out.psf"
write psf card unit 25
close unit 25

open read card name peptide_out.psf unit 30
read psf card unit 30
close unit 30

# !read coor
open read card name ../charmm/peptide.pdb unit 20
read coor pdb unit 20
close unit 20

ic para
hbuild

# !read gbsw CMAP parameter
open read card name ../../../data/par_all22_prot_gbsw.inp unit 15
read parameter card unit 15
close unit 15

set temp = 303.15

wrnlev 5
prnlev 0 
stream ../../../data/radii_prot_na.str
stream ../../../data/radius_gbsw.str
stream ../../../data/radius.str
prnlev 5

CONS hmcm Force 100.0 weig refx 0.0 refy 0.0 refz 30.0 sele segid PROA end

scalar wmain statistics select .not. type H* end
define check select ( .not. type H* ) .and. ( property wmain .eq. 0.0 ) show end
if ?nsel ne 0 stop

GBSW SW 0.3 RMAX 20.0 NANG 38 SGAMMA 0.04 TMEMB 30 MSW 2.5 CONC 0.15 TEMP @temp GBENER

NBOND atom switch cdie vdw vswitch ctonnb 12 ctofnb 14 cutnb 18

open read card name ../toppar/4.1top_all36_prot.rtf unit 10
read rtf card unit 10
close unit 10

open read card name ../toppar/2_1par_all36m_prot.prm unit 10
read parameter card unit 10
close unit 10

# !ENERGY

mini abnr nstep 1000 nprint 10 step 0.002 inbfrq 10

energy

NBOND nbxmod 5 atom rdiel shift vatom vdistance vshift -
      cutnb 8.0 ctofnb 7.5 ctonnb 6.5 eps 2.0 e14fac 0.4 wmin 1.5
COOR SURF SELE all END

COOR SURF RPROBE 1.4 SELE all END
SCALAR WMAIN STAT SELE all END
SCALAR WMAIN SET 0 SELE ALL END


COOR SURF RPROBE 1.4 SELE type O* .or. type N* END
SCALAR WMAIN STAT SELE all END
SCALAR WMAIN SET 0 SELE ALL END


COOR SURF RPROBE 1.4 SELE .not. (type O* .or. type N*) END
SCALAR WMAIN STAT SELE all END
SCALAR WMAIN SET 0 SELE ALL END

NBOND atom switch cdie vdw vswitch ctonnb 12 ctofnb 14 cutnb 18

coor hbond select segid PROA end

open write unform name gbsw_out.rst unit 26
open write unform name gbsw_out.dcd unit 26

shake BONH para tol 1.0d-07

scalar fbeta set 3.0 select all end
scalar fbeta set 0.0 select type H* end
DYNA LEAP LANGEVIN start  NSTEP 1000000 TIMEstp 0.0005 NPRINT 2000 -
     INBFRQ 25 TBATH 303.15 FIRSTT 303.15 FINALt 303.15 TSTRUC 303.15 - 
     IHBFrq -1 NSAVcrd 2000 ISEED 12345 IUNCRD 26

SHAKE OFF

mini abnr nstep 1000 nprint 10

close unit 25


stop
    """
    return gbsw_script

# %% [markdown]
# ### charmm.inpをvalue_workへ入れる

# %%
#作成したcharmm.inpをコピーディレクトリに入れる関数
import os

def in_charminp(value):
    # CHARMMスクリプトを生成
    charmm = seed_charmm(input_list)
    # ディレクトリとファイルパスを設定
    directory = f"/Users/teraimao/experiment/work/{value}_work/charmm"
    destination_path = f"{directory}/charmm.inp"
    
    # ディレクトリが存在しない場合は作成
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    # ファイルに書き込む
    with open(destination_path, 'w') as file:
        file.write(charmm)

# %% [markdown]
# ### gbsw_inのcharmm.inpをvalue_workへ入れる

# %%
import os

def in_gbsw_in(value):
    # gbsw_in の作成と保存
    gbsw_in = gbsw_in_charmm(input_list)
    directory = f"/Users/teraimao/experiment/work/{value}_work/gbsw_in"
    destination_path = f"{directory}/charmm.inp"
        
    # ディレクトリが存在しない場合は作成
    if not os.path.exists(directory):
        os.makedirs(directory)
        
    # ファイルに書き込む
    with open(destination_path, 'w') as file:
        file.write(gbsw_in)

# %% [markdown]
# ### gbsw_surのcharmm.inpをvalue_workへ入れる

# %%
import os

def in_gbsw_sur(value):
    # gbsw_in の作成と保存
    gbsw_sur = gbsw_sur_charmm(input_list)
    directory = f"/Users/teraimao/experiment/work/{value}_work/gbsw_sur"
    destination_path = f"{directory}/charmm.inp"
        
    # ディレクトリが存在しない場合は作成
    if not os.path.exists(directory):
        os.makedirs(directory)
        
    # ファイルに書き込む
    with open(destination_path, 'w') as file:
        file.write(gbsw_sur)

# %% [markdown]
# ### gbsw_outのcharmm.inp⇨value_work

# %%
import os

def in_gbsw_out(value):
    # gbsw_in の作成と保存
    gbsw_out = gbsw_out_charmm(input_list)
    directory = f"/Users/teraimao/experiment/work/{value}_work/gbsw_out"
    destination_path = f"{directory}/charmm.inp"
        
    # ディレクトリが存在しない場合は作成
    if not os.path.exists(directory):
        os.makedirs(directory)
        
    # ファイルに書き込む
    with open(destination_path, 'w') as file:
        file.write(gbsw_out)

# %% [markdown]
# ### サーバーに接続

# %%
#サーバーに接続する関数
import paramiko
def connect_server():
    hostname = '192.168.11.20'  # サーバーのホスト名
    username = 'teraimao'  # サーバーに接続するユーザー名
    password = '10Ap1128'  # ユーザーのパスワード
    try:
        client = paramiko.SSHClient()
        client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
        client.connect(hostname, username=username, password=password)
        return client
    except paramiko.AuthenticationException:
        print("Authentication failed, please verify your credentials.")
    except paramiko.SSHException as sshException:
        print(f"Unable to establish SSH connection: {sshException}")
    except Exception as e:
        print(f"Operation error: {e}")
    return None

# %% [markdown]
# ### 計算ノードに接続する

# %%
#計算ノードに接続するコード
import time
def connect_compute_node():
    compute_node = "frigate03"  # 計算ノードのホスト名
    client = connect_server()
    if not client:
        return None
    try:
        # シェルセッションを開く
        session = client.invoke_shell()
        time.sleep(1)  # 少し待機してシェルが準備されるのを待つ

        # 計算ノードに接続
        session.send(f"ssh {compute_node}\n")
        time.sleep(1)  # 接続が確立するのを待つ

        # バッファの読み取り
        output = session.recv(1024).decode('utf-8')
        print(f"Connected to compute node {compute_node}:\n{output}")

        # 継続して操作する場合、セッションを返す
        return session
    except Exception as e:
        print(f"Failed to connect to compute node {compute_node}: {e}")
        return None

# メイン部分
#if __name__ == "__main__":
 #   session = connect_compute_node()
  #  if session:
   #     print("Compute node session established. Ready for commands.")
    #else:
     #   print("Failed to establish a compute node session.")

# %% [markdown]
# ### コピーディレクトリをサーバーに

# %%
#コピーディレクトリをサーバーに送る関数
def send_dir(value):
    client = connect_server()
    if client is None:
        print("Failed to connect to the server.")
        return
    
    sftp = client.open_sftp()
    local_path = f"/Users/teraimao/experiment/work/{value}_work/"
    remote_path = f'/home/teraimao/experiment/work/{value}_work'

    try:
        sftp.stat(remote_path)
    except FileNotFoundError:
        sftp.mkdir(remote_path)

    try:
        # ディレクトリとファイルを再帰的にアップロード
        upload_directory(sftp, local_path, remote_path)
    except Exception as e:
        print(f"An error occurred in upload_directory: {e}")

    try:
        run_csh(value)
    except Exception as e:
        print(f"An error occurred in run_csh: {e}")
    finally:
        sftp.close()  # SFTPセッションを閉じる
        client.close()  # SSHクライアントを閉じる

# %%
#コピーディレクトリの中身をサーバーに送る関数
def upload_directory(sftp, local_path, remote_path):
    for item in os.listdir(local_path):
        local_item = os.path.join(local_path, item)
        remote_item = os.path.join(remote_path, item)

        if os.path.isdir(local_item):
            try:
                sftp.stat(remote_item)
            except FileNotFoundError:
                sftp.mkdir(remote_item)
            upload_directory(sftp, local_item, remote_item)
        else:
            sftp.put(local_item, remote_item)

# %%
#charmmディレクトリのrun.cshを実行するコマンド
def run_csh(value):
    client = connect_server()
    if client is None:
        print("Failed to connect to the server.")
        return

    remote_directory = f'/home/teraimao/experiment/work/{value}_work/charmm'
    chmod_command = f'cd {remote_directory} && chmod +x Run.csh'
    run_command = f'cd {remote_directory} && ./Run.csh'

    try:
        client.exec_command(chmod_command)
        stdin, stdout, stderr = client.exec_command(run_command)
        output = stdout.read().decode()
        error = stderr.read().decode()
        
        if output:
            print("Output:\n", output)
        if error:
            print("Error:\n", error)

    except Exception as e:
        print(f"An error occurred while executing the script: {e}")
    finally:
        client.close()

# %%
#gbsw_のrun.shを実行するコマンド
def run_sh_gbsw(value):
    client = connect_server()
    if client is None:
        print("Failed to connect to the server.")
        return

    peptide_position = ["in", "sur", "out"]

    try:
        for i in peptide_position:
            remote_directory = f'/home/teraimao/experiment/work/{value}_work/gbsw_{i}'
            chmod_command = f'cd {remote_directory} && chmod +x Run.csh'
            run_command = f'cd {remote_directory} && ./Run.csh'
            
            # chmodコマンドの実行
            stdin, stdout, stderr = client.exec_command(chmod_command)
            chmod_error = stderr.read().decode()
            if chmod_error:
                print(f"Error during chmod in {remote_directory}:\n{chmod_error}")
                continue  # 次のディレクトリに移行

            # Run.cshの実行
            stdin, stdout, stderr = client.exec_command(run_command)
            output = stdout.read().decode()
            error = stderr.read().decode()

            if output:
                print(f"Output from {remote_directory}:\n{output}")
            if error:
                print(f"Error from {remote_directory}:\n{error}")

    except Exception as e:
        print(f"An error occurred while executing the script: {e}")
    finally:
        client.close()

# %% [markdown]
# ### 分子内水素結合を計算する

# %%
#分子内水素結合を計算するコマンド
def run_sh_hbond(value):
    client = connect_server()
    if client is None:
        print("Failed to connect to the server.")
        return

    peptide_position = ["in", "sur", "out"]

    try:
        for i in peptide_position:
            remote_directory = f'/home/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{i}/hbond'
            chmod_command = f'cd {remote_directory} && chmod +x Run.csh'
            run_command = f'cd {remote_directory} && ./Run.csh'
            
            # chmodコマンドの実行
            stdin, stdout, stderr = client.exec_command(chmod_command)
            chmod_error = stderr.read().decode()
            if chmod_error:
                print(f"Error during chmod in {remote_directory}:\n{chmod_error}")
                continue  # 次のディレクトリに移行

            # Run.cshの実行
            stdin, stdout, stderr = client.exec_command(run_command)
            output = stdout.read().decode()
            error = stderr.read().decode()

            if output:
                print(f"Output from {remote_directory}:\n{output}")
            if error:
                print(f"Error from {remote_directory}:\n{error}")

    except Exception as e:
        print(f"An error occurred while executing the script: {e}")
    finally:
        client.close()

# %% [markdown]
# ### 溶媒露出表面積の計算

# %%
#溶媒露出表面積の計算
def run_sh_surf(value):
    client = connect_server()
    if client is None:
        print("Failed to connect to the server.")
        return

    peptide_position = ["in", "sur", "out"]

    try:
        for i in peptide_position:
            remote_directory = f'/home/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{i}/surf_area'
            chmod_command = f'cd {remote_directory} && chmod +x Run.csh'
            run_command = f'cd {remote_directory} && ./Run.csh'
            
            # chmodコマンドの実行
            stdin, stdout, stderr = client.exec_command(chmod_command)
            chmod_error = stderr.read().decode()
            if chmod_error:
                print(f"Error during chmod in {remote_directory}:\n{chmod_error}")
                continue  # 次のディレクトリに移行

            # Run.cshの実行
            stdin, stdout, stderr = client.exec_command(run_command)
            output = stdout.read().decode()
            error = stderr.read().decode()

            if output:
                print(f"Output from {remote_directory}:\n{output}")
            if error:
                print(f"Error from {remote_directory}:\n{error}")

    except Exception as e:
        print(f"An error occurred while executing the script: {e}")
    finally:
        client.close()

# %%
# 計算済みディレクトリをMacにコピーする関数
import paramiko
from scp import SCPClient

def return_copy_work(value):
    client = connect_server()
    if client is None:
        print("Failed to connect to the server.")
        return

    # リモートとローカルのパスを定義
    remote_path = f"/home/teraimao/experiment/work/{value}_work"
    local_path = f"/Users/teraimao/experiment/work/"

    try:
        with SCPClient(client.get_transport()) as scp:
            print(f"Downloading {remote_path} to {local_path} ...")
            scp.get(remote_path, local_path, recursive=True)  # recursive=Trueでディレクトリ対応
            print("Download complete!")

    except Exception as e:
        print(f"Error: {e}")

    finally:
        client.close()

# %%
#後半100psの溶媒和自由エネルギーをまとめるコード
def summarize_solv_free_ene(value):
    peptide_positions = ["in", "sur", "out"]  # 修正: 配列名をわかりやすく変更
    
    try:
        for position in peptide_positions:
            # 動的にawkコマンドを生成
            awk_command = f"""
            awk '/^DYNA>/ {{time = $3; next}} /^DYNA PBEQ>/ {{if (time >= 400 && time <= 500) print time, $5}}' \\
            /Users/teraimao/experiment/work/{value}_work/gbsw_{position}/log > \\
            /Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{position}/solv_free_ener/output.dat
            """
            
            # コマンドを実行
            subprocess.run(awk_command, shell=True, check=True)
            print(f"Command executed successfully for position: {position}")
    
    except subprocess.CalledProcessError as e:
        print(f"An error occurred for position {position}: {e}")

# %%
#後半100psのファンデルワールスエネルギーをまとめるコード
def summarize_van_der_ener(value):
    peptide_positions = ["in", "sur", "out"]  # 修正: 配列名をわかりやすく変更
    
    try:
        for position in peptide_positions:
            # 動的にawkコマンドを生成
            awk_command = f"""
            awk '/^DYNA>/ {{time = $3; next}} /^DYNA EXTERN>/ {{if (time >= 400 && time <= 500) print time, $3}}' \\
            /Users/teraimao/experiment/work/{value}_work/gbsw_{position}/log > \\
            /Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{position}/van_der_ener/output.dat
            """
            # コマンドを実行
            subprocess.run(awk_command, shell=True, check=True)
            print(f"Command executed successfully for position: {position}")
    
    except subprocess.CalledProcessError as e:
        print(f"An error occurred for position {position}: {e}")

# %%
#後半100psのクーロン相互作用エネルギーをまとめるコード
def summarize_coul_ener(value):
    peptide_positions = ["in", "sur", "out"]  # 修正: 配列名をわかりやすく変更
    
    try:
        for position in peptide_positions:
            # 動的にawkコマンドを生成
            awk_command = f"""
            awk '/^DYNA>/ {{time = $3; next}} /^DYNA EXTERN>/ {{if (time >= 400 && time <= 500) print time, $4}}' \\
            /Users/teraimao/experiment/work/{value}_work/gbsw_{position}/log > \\
            /Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{position}/coul_ener/output.dat
            """
            
            # コマンドを実行
            subprocess.run(awk_command, shell=True, check=True)
            print(f"Command executed successfully for position: {position}")
    
    except subprocess.CalledProcessError as e:
        print(f"An error occurred for position {position}: {e}")

# %%
#後半100ps系の全ての平均値を計算しaverageディレクトリに入れていく
import os

def calculate_column_average(value):
    column_index = 1  # 平均を計算する列（2列目）
    time_index = 0    # 時間列（1列目）
    peptide_positions = ["in", "sur", "out"]
    directories = ["solv_free_ener", "van_der_ener", "coul_ener"]

    try:
        for position in peptide_positions:
            for directory in directories:
                dir_path = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{position}/{directory}"

                # ディレクトリ内のファイルをリスト
                if not os.path.isdir(dir_path):
                    print(f"Directory not found: {dir_path}")
                    continue

                data_files = [f for f in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, f))]
                if not data_files:
                    print(f"No files found in directory: {dir_path}")
                    continue

                # 最初のファイルを選択（複数ファイルがある場合は要確認）
                file_path = os.path.join(dir_path, data_files[0])
                values = []

                print(f"Reading file: {file_path}")
                try:
                    with open(file_path, 'r') as file:
                        for line in file:
                            if not line.strip():  # 空行をスキップ
                                continue
                            columns = line.split()
                            time = float(columns[time_index])  # 時間列を取得
                            if time >= 400.0:  # 時間が40以上の場合のみ値を取得
                                values.append(float(columns[column_index]))
                                print(f"Valid data: {line.strip()}")
                except FileNotFoundError:
                    print(f"File not found: {file_path}")
                    continue
                except ValueError:
                    print(f"Invalid data format in file: {file_path}")
                    continue

                # 平均を計算
                if values:
                    average = sum(values) / len(values)
                    print(f"Calculated average: {average}")
                else:
                    print(f"No valid values found in {file_path} for averaging.")
                    average = 0.0

                # 保存先ディレクトリを作成
                average_dir_path = os.path.join(dir_path, "average")
                os.makedirs(average_dir_path, exist_ok=True)

                # 結果を保存
                average_file_path = os.path.join(average_dir_path, "result.txt")
                try:
                    with open(average_file_path, 'w') as avg_file:
                        avg_file.write(f"{average:.6f}\n")  # 小数点以下6桁で保存
                        print(f"Average value saved to {average_file_path}")
                except Exception as e:
                    print(f"Failed to write average to {average_file_path}: {e}")

    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
#後半100psのhbondの平均を求めるコード
import os

def calculate_hbond_average(value):
    column_index = 1  # 水素結合数がある列（2列目）
    time_index = 0    # 計算時間がある列（1列目）
    peptide_positions = ["in", "sur", "out"]  # 各位置で処理
    directory = "hbond"  # hbond専用ディレクトリ名

    try:
        for position in peptide_positions:
            dir_path = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{position}/{directory}"

            # ディレクトリ内のファイルをリスト
            if not os.path.isdir(dir_path):
                print(f"Directory not found: {dir_path}")
                continue

            data_files = [f for f in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, f))]
            if not data_files:
                print(f"No files found in directory: {dir_path}")
                continue

            # 最初のファイルを選択（複数ファイルがある場合は要確認）
            file_path = os.path.join(dir_path, data_files[0])
            values = []

            print(f"Reading hbond file: {file_path}")
            try:
                with open(file_path, 'r') as file:
                    # ヘッダー行をスキップ
                    next(file)

                    # データ行を読み取る
                    for line in file:
                        if not line.strip():  # 空行をスキップ
                            continue
                        columns = line.split()
                        time = float(columns[time_index])  # 時間列を取得
                        if time >= 400.0:  # 時間が40以上の場合のみ値を取得
                            values.append(float(columns[column_index]))
                            print(f"Valid hbond data: {line.strip()}")
            except FileNotFoundError:
                print(f"File not found: {file_path}")
                continue
            except ValueError:
                print(f"Invalid data format in file: {file_path}")
                continue

            # 平均を計算
            if values:
                average = sum(values) / len(values)
                print(f"Calculated hbond average: {average}")
            else:
                print(f"No valid hbond values found in {file_path} for averaging.")
                average = 0.0

            # 保存先ディレクトリを作成
            average_dir_path = os.path.join(dir_path, "average")
            os.makedirs(average_dir_path, exist_ok=True)

            # 結果を保存
            average_file_path = os.path.join(average_dir_path, "result.txt")
            try:
                with open(average_file_path, 'w') as avg_file:
                    avg_file.write(f"{average:.6f}\n")  # 小数点以下6桁で保存
                    print(f"Average hbond value saved to {average_file_path}")
            except Exception as e:
                print(f"Failed to write hbond average to {average_file_path}: {e}")

    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
#後半10psの溶媒露出表面積の平均を求めるコード
import os

def calculate_surf_average(value):
    column_indices = [1, 2, 3, 4]  # 2列目、3列目、4列目、5列目のインデックス
    time_index = 0  # 計算時間のインデックス
    peptide_positions = ["in", "sur", "out"]  # 各位置で処理
    directory = "surf_area"  # hbond専用ディレクトリ名

    try:
        for position in peptide_positions:
            dir_path = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{position}/{directory}"

            # ディレクトリの存在確認
            if not os.path.isdir(dir_path):
                print(f"Directory not found: {dir_path}")
                continue

            # ディレクトリ内のファイルをリストアップ
            data_files = [f for f in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, f))]
            if not data_files:
                print(f"No files found in directory: {dir_path}")
                continue

            # 最初のファイルを選択（複数ファイルがある場合は要確認）
            file_path = os.path.join(dir_path, data_files[0])
            column_values = {index: [] for index in column_indices}

            with open(file_path, 'r') as file:
                next(file)  # ヘッダーをスキップ
                for line in file:
                    if not line.strip():  # 空行をスキップ
                        continue
                    columns = line.split()
                    time = float(columns[time_index])  # 時間列を取得
                    if time >= 400.0:  # 時間が40以上の場合のみ値を取得
                        for index in column_indices:
                            column_values[index].append(float(columns[index]))

            # 各列の平均を計算
            averages = {
                index: (sum(column_values[index]) / len(column_values[index])) if column_values[index] else 0.0
                for index in column_indices
            }

            # データがなかった場合の処理
            if not any(column_values.values()):
                print(f"No valid hbond values found in {file_path} for averaging.")
                continue

            # "average" ディレクトリを作成
            average_dir_path = os.path.join(dir_path, "average")
            os.makedirs(average_dir_path, exist_ok=True)

            # 結果を保存
            average_file_path = os.path.join(average_dir_path, "result.txt")
            try:
                with open(average_file_path, 'w') as avg_file:
                    for index, avg in averages.items():
                        avg_file.write(f"Column {index+1} average: {avg:.6f}\n")
                    print(f"Averages saved to {average_file_path}")
            except Exception as e:
                print(f"Failed to write averages to {average_file_path}: {e}")

    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
#平均値を計算する必要のない表面積を解析ディレクトリに入れる
import os
from collections import OrderedDict

def extract_total_from_log(log_file, target_commands):
    """ログファイルから指定されたターゲットコマンドの次の `total =` の値を抽出する"""
    target_areas = OrderedDict((cmd, None) for cmd in target_commands)  # 順番を保証する辞書

    try:
        with open(log_file, 'r') as file:
            lines = file.readlines()
            for i, line in enumerate(lines):
                for key in target_areas.keys():
                    if key in line:  # ターゲットコマンドを検出
                        for j in range(i + 1, len(lines)):
                            if "total  =" in lines[j]:
                                target_areas[key] = lines[j].split()[-1]  # 値を取得
                                break
        return target_areas
    except FileNotFoundError:
        print(f"Log file not found: {log_file}")
        return None
    except Exception as e:
        print(f"Error reading log file: {e}")
        return None

def save_results(value):
    peptide_positions = ["in", "sur", "out"]
    target_commands = [
        "COOR SURF RPROBE 1.4 SELE all END",  # surf_area 用
        "COOR SURF RPROBE 1.4 SELE type O* .or. type N* END",  # polar_surf_area 用
    ]

    for position in peptide_positions:
        # パスの定義
        log_file = f"/Users/teraimao/experiment/work/{value}_work/gbsw_{position}/log"
        dir_polar = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{position}/polar_surf_area/average"
        dir_surf = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{position}/surf_area/average"

        # ログファイルからデータを抽出
        target_areas = extract_total_from_log(log_file, target_commands)
        if not target_areas:
            print(f"Skipping {log_file} due to missing or invalid data.")
            continue

        # 値を保存
        if None not in target_areas.values():  # 全てのターゲットが見つかった場合
            os.makedirs(dir_polar, exist_ok=True)
            os.makedirs(dir_surf, exist_ok=True)

            # 正しい対応関係で保存する
            with open(os.path.join(dir_surf, "result.txt"), 'w') as file_surf:
                file_surf.write(target_areas["COOR SURF RPROBE 1.4 SELE all END"] + "\n")

            with open(os.path.join(dir_polar, "result.txt"), 'w') as file_polar:
                file_polar.write(target_areas["COOR SURF RPROBE 1.4 SELE type O* .or. type N* END"] + "\n")

            print(f"Values saved successfully for {position}:")
            print(f" - {target_areas['COOR SURF RPROBE 1.4 SELE all END']} saved to {os.path.join(dir_surf, 'result.txt')}")
            print(f" - {target_areas['COOR SURF RPROBE 1.4 SELE type O* .or. type N* END']} saved to {os.path.join(dir_polar, 'result.txt')}")
        else:
            print(f"Error: Missing data for some target commands in {log_file}.")

# %% [markdown]
# ### 入力csv情報から必要なデータを新csv

# %%
#入力したcsvデータから必要なデータを水中、膜中、表面別に新しいcsvファイルに入れるコード
import pandas as pd
import ast

def in_csv(file_path):
    # 許容されるアミノ酸のリスト
    kind = ['G','A','V','L','I','C','M','S','T','D','E','N','Q','R',
                'K','H','F','Y','W','P','dA','dV','dL','dI','dC','dM',
                'dS','dT','dD','dE','dN','dQ','dR','dK','dH','dF','dY','dW','dP',
               'Abu','meG','Me_Bmt(E)','meL','meV','meA','meI','meM','meS','meT',
                'meD','meN','meQ','meK','meH','meF','meY','meW']

    # 入力データを読み込む
    try:
        data = pd.read_csv(file_path)
        csv_list = data[['CycPeptMPDB_ID', 'Sequence', 'Sequence_TPSA', 'TPSA', 'Permeability']]
    except Exception as e:
        print(f"Error reading input CSV file: {e}")
        return

    # ペプチドの位置
    peptide_positions = ["in", "sur", "out"]

    # 結果を格納するリスト
    result_data = []

    for row in csv_list.itertuples(index=False):
        try:
            # Sequence をリスト形式に変換
            seq_list = ast.literal_eval(row.Sequence)
            seq_id = row.CycPeptMPDB_ID
            seq_tpsa = row.Sequence_TPSA
            tpsa = row.TPSA
            permeability = row.Permeability  # Permeability 列から取得

            if all(acid in kind for acid in seq_list):
                # 条件を突破したデータをリストに格納
                result_data.append({
                    'CycPeptMPDB_ID': seq_id,
                    'Sequence': seq_list,
                    'Sequence_TPSA': seq_tpsa,
                    'TPSA': tpsa,
                    'Permeability': permeability
                })

        except Exception as e:
            print(f"Error processing row {row}: {e}")

    # DataFrame に変換
    result_df = pd.DataFrame(result_data)

    # CSV ファイルに追記または新規作成
    for pos in peptide_positions:
        output_file = f"/Users/teraimao/experiment/data/csv_data/experiment_data_{pos}.csv"
        try:
            # 既存データを読み込む
            existing_df = pd.read_csv(output_file)
            # ID に基づいて重複を排除
            combined_df = pd.concat([existing_df, result_df]).drop_duplicates(subset='CycPeptMPDB_ID', keep='last')
        except FileNotFoundError:
            # ファイルがない場合は新規作成
            combined_df = result_df

        # CSV ファイルに保存
        try:
            combined_df.to_csv(output_file, index=False)
            print(f"Data successfully written to {output_file}")
        except Exception as e:
            print(f"Error writing to {output_file}: {e}")

# %% [markdown]
# ### inの計算結果をcsvに

# %%
#inの計算結果をcsvファイルに入れるコード
import os
import pandas as pd
import re  # 正規表現を使ってデータを抽出

def update_csv_in(value):
    # エネルギー関連のデータマッピングリスト
    csv_list = ['coul_ener', 'hbond', 'van_der_ener', 'solv_free_ener']
    csv_experiment_data = ['クーロン相互作用エネルギー', '分子内水素結合数', 'ファンデルワールスエネルギー', '溶媒和自由エネルギー']
    
    # 溶媒露出表面積関連のデータマッピング
    surf_map = {
        2: '溶媒露出表面積',
        3: '疎水性残基溶媒露出表面積',
        4: '極性残基溶媒露出表面積',
        5: '荷電残基溶媒露出表面積'
    }

    csv_file = "/Users/teraimao/experiment/data/csv_data/experiment_data_in.csv"

    # 各値を保存する辞書
    results = {}

    # **エネルギー関連の値を取得**
    for j, column_name in zip(csv_list, csv_experiment_data):
        result_file = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_in/{j}/average/result.txt"

        if os.path.isdir(result_file):
            print(f"Error: {result_file} is a directory.")
            continue

        os.makedirs(os.path.dirname(result_file), exist_ok=True)

        if not os.path.exists(result_file):
            with open(result_file, 'w') as file:
                file.write("0.0\n")

        try:
            with open(result_file, 'r') as file:
                file_value = file.readline().strip()
                results[column_name] = float(file_value) if file_value else 0.0
        except Exception as e:
            print(f"Error reading {result_file}: {e}")
            results[column_name] = 0.0

    # **溶媒露出表面積関連の値を取得**
    surf_file = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_in/surf_area/average/result.txt"
    if os.path.exists(surf_file) and not os.path.isdir(surf_file):
        try:
            with open(surf_file, 'r') as file:
                for line in file:
                    match = re.match(r"Column (\d+) average: ([\d\.]+)", line.strip())
                    if match:
                        col_num = int(match.group(1))  # 列番号
                        avg_value = float(match.group(2))  # 平均値
                        if col_num in surf_map:
                            results[surf_map[col_num]] = avg_value
        except Exception as e:
            print(f"Error reading {surf_file}: {e}")
    else:
        print(f"Warning: {surf_file} not found. Initializing values as 0.")
        for col_num in surf_map:
            results[surf_map[col_num]] = 0.0

    # **CSV ファイルの更新**
    try:
        if os.path.exists(csv_file):
            df = pd.read_csv(csv_file)
        else:
            df = pd.DataFrame(columns=['CycPeptMPDB_ID'] + list(results.keys()))
            print(f"Created a new CSV file: {csv_file}")

        for column_name in results.keys():
            if column_name not in df.columns:
                df[column_name] = None

        if value in df['CycPeptMPDB_ID'].values:
            for column_name, result_value in results.items():
                if pd.isna(df.loc[df['CycPeptMPDB_ID'] == value, column_name].iloc[0]):
                    df.loc[df['CycPeptMPDB_ID'] == value, column_name] = result_value
        else:
            new_row = {'CycPeptMPDB_ID': value, **results}
            df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)

        df.to_csv(csv_file, index=False)
        print(f"Updated CSV file saved: {csv_file}")
    except Exception as e:
        print(f"Error updating CSV file: {e}")

# %% [markdown]
# ### surの計算結果をcsvに

# %%
#surの計算結果をcsvファイルに入れるコード
import os
import pandas as pd
import re  # 正規表現を使ってデータを抽出

def update_csv_sur(value):
    # エネルギー関連のデータマッピングリスト
    csv_list = ['coul_ener', 'hbond', 'van_der_ener', 'solv_free_ener']
    csv_experiment_data = ['クーロン相互作用エネルギー', '分子内水素結合数', 'ファンデルワールスエネルギー', '溶媒和自由エネルギー']
    
    # 溶媒露出表面積関連のデータマッピング
    surf_map = {
        2: '溶媒露出表面積',
        3: '疎水性残基溶媒露出表面積',
        4: '極性残基溶媒露出表面積',
        5: '荷電残基溶媒露出表面積'
    }

    csv_file = "/Users/teraimao/experiment/data/csv_data/experiment_data_sur.csv"

    # 各値を保存する辞書
    results = {}

    # **エネルギー関連の値を取得**
    for j, column_name in zip(csv_list, csv_experiment_data):
        result_file = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_sur/{j}/average/result.txt"

        if os.path.isdir(result_file):
            print(f"Error: {result_file} is a directory.")
            continue

        os.makedirs(os.path.dirname(result_file), exist_ok=True)

        if not os.path.exists(result_file):
            with open(result_file, 'w') as file:
                file.write("0.0\n")

        try:
            with open(result_file, 'r') as file:
                file_value = file.readline().strip()
                results[column_name] = float(file_value) if file_value else 0.0
        except Exception as e:
            print(f"Error reading {result_file}: {e}")
            results[column_name] = 0.0

    # **溶媒露出表面積関連の値を取得**
    surf_file = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_sur/surf_area/average/result.txt"
    if os.path.exists(surf_file) and not os.path.isdir(surf_file):
        try:
            with open(surf_file, 'r') as file:
                for line in file:
                    match = re.match(r"Column (\d+) average: ([\d\.]+)", line.strip())
                    if match:
                        col_num = int(match.group(1))  # 列番号
                        avg_value = float(match.group(2))  # 平均値
                        if col_num in surf_map:
                            results[surf_map[col_num]] = avg_value
        except Exception as e:
            print(f"Error reading {surf_file}: {e}")
    else:
        print(f"Warning: {surf_file} not found. Initializing values as 0.")
        for col_num in surf_map:
            results[surf_map[col_num]] = 0.0

    # **CSV ファイルの更新**
    try:
        if os.path.exists(csv_file):
            df = pd.read_csv(csv_file)
        else:
            df = pd.DataFrame(columns=['CycPeptMPDB_ID'] + list(results.keys()))
            print(f"Created a new CSV file: {csv_file}")

        for column_name in results.keys():
            if column_name not in df.columns:
                df[column_name] = None

        if value in df['CycPeptMPDB_ID'].values:
            for column_name, result_value in results.items():
                if pd.isna(df.loc[df['CycPeptMPDB_ID'] == value, column_name].iloc[0]):
                    df.loc[df['CycPeptMPDB_ID'] == value, column_name] = result_value
        else:
            new_row = {'CycPeptMPDB_ID': value, **results}
            df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)

        df.to_csv(csv_file, index=False)
        print(f"Updated CSV file saved: {csv_file}")
    except Exception as e:
        print(f"Error updating CSV file: {e}")

# %% [markdown]
# ### outの計算結果をcsvに

# %%
#outの計算結果をcsvファイルに入れるコード
import os
import pandas as pd
import re  # 正規表現を使ってデータを抽出

def update_csv_out(value):
    # エネルギー関連のデータマッピングリスト
    csv_list = ['coul_ener', 'hbond', 'van_der_ener', 'solv_free_ener']
    csv_experiment_data = ['クーロン相互作用エネルギー', '分子内水素結合数', 'ファンデルワールスエネルギー', '溶媒和自由エネルギー']
    
    # 溶媒露出表面積関連のデータマッピング
    surf_map = {
        2: '溶媒露出表面積',
        3: '疎水性残基溶媒露出表面積',
        4: '極性残基溶媒露出表面積',
        5: '荷電残基溶媒露出表面積'
    }

    csv_file = "/Users/teraimao/experiment/data/csv_data/experiment_data_out.csv"

    # 各値を保存する辞書
    results = {}

    # **エネルギー関連の値を取得**
    for j, column_name in zip(csv_list, csv_experiment_data):
        result_file = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_out/{j}/average/result.txt"

        if os.path.isdir(result_file):
            print(f"Error: {result_file} is a directory.")
            continue

        os.makedirs(os.path.dirname(result_file), exist_ok=True)

        if not os.path.exists(result_file):
            with open(result_file, 'w') as file:
                file.write("0.0\n")

        try:
            with open(result_file, 'r') as file:
                file_value = file.readline().strip()
                results[column_name] = float(file_value) if file_value else 0.0
        except Exception as e:
            print(f"Error reading {result_file}: {e}")
            results[column_name] = 0.0

    # **溶媒露出表面積関連の値を取得**
    surf_file = f"/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_out/surf_area/average/result.txt"
    if os.path.exists(surf_file) and not os.path.isdir(surf_file):
        try:
            with open(surf_file, 'r') as file:
                for line in file:
                    match = re.match(r"Column (\d+) average: ([\d\.]+)", line.strip())
                    if match:
                        col_num = int(match.group(1))  # 列番号
                        avg_value = float(match.group(2))  # 平均値
                        if col_num in surf_map:
                            results[surf_map[col_num]] = avg_value
        except Exception as e:
            print(f"Error reading {surf_file}: {e}")
    else:
        print(f"Warning: {surf_file} not found. Initializing values as 0.")
        for col_num in surf_map:
            results[surf_map[col_num]] = 0.0

    # **CSV ファイルの更新**
    try:
        if os.path.exists(csv_file):
            df = pd.read_csv(csv_file)
        else:
            df = pd.DataFrame(columns=['CycPeptMPDB_ID'] + list(results.keys()))
            print(f"Created a new CSV file: {csv_file}")

        for column_name in results.keys():
            if column_name not in df.columns:
                df[column_name] = None

        if value in df['CycPeptMPDB_ID'].values:
            for column_name, result_value in results.items():
                if pd.isna(df.loc[df['CycPeptMPDB_ID'] == value, column_name].iloc[0]):
                    df.loc[df['CycPeptMPDB_ID'] == value, column_name] = result_value
        else:
            new_row = {'CycPeptMPDB_ID': value, **results}
            df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)

        df.to_csv(csv_file, index=False)
        print(f"Updated CSV file saved: {csv_file}")
    except Exception as e:
        print(f"Error updating CSV file: {e}")

# %% [markdown]
# ### RMSD

# %%
import os
import MDAnalysis as mda
from MDAnalysis.analysis import rms
import numpy as np

def RMSD(output_file="rmsd.dat"):
    # 入力ファイルのパス
    psf_file_path = '/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_in/peptide_in.psf'
    dcd_file_path = '/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_in/gbsw_in.dcd'

    # 出力ディレクトリの確認と作成
    output_dir = os.path.dirname(output_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)  # ディレクトリが存在しない場合に作成
        print(f"Output directory created: {output_dir}")

    # ユニバースを作成 (構造ファイル + DCD)
    u = mda.Universe(psf_file_path, dcd_file_path)

    # 参照構造を作成 (最初のフレームを参照構造として扱う)
    ref_frame = 400
    ref = mda.Universe('/Users/teraimao/experiment/work/0_18_35_K,N,S,Y,F_work/gbsw_out/peptide_out.psf',
                       '/Users/teraimao/experiment/work/0_18_35_K,N,S,Y,F_work/gbsw_out/gbsw_out.dcd')
    ref.trajectory[ref_frame]
    ref_atoms = ref.select_atoms("all")
    mobile_atoms = u.select_atoms("all")

    # RMSD 計算
    R = rms.RMSD(mobile_atoms, ref_atoms)
    R.run()

    # 結果を出力 (非推奨警告対応: `R.results.rmsd` を使用)
    data = R.results.rmsd  # numpy array: [frame, time(ps), RMSD(Å)]

    # 出力ファイルを保存
    np.savetxt(output_file, data, header="Frame Time(ps) RMSD(Å)", fmt="%8d %8.3f %8.3f")
    print(f"RMSD results saved to: {output_file}")
    print(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 import MDAnalysis as mda
#       3 from MDAnalysis.analysis import rms
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'MDAnalysis'

# %%
# 実行例
output_file_path = '/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_in/out_to_rmsd.dat'
RMSD(output_file=output_file_path)
# Out:
# RMSD results saved to: /Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_in/out_to_rmsd.dat
# [[  0.           0.99999991   2.35306458]
#  [  1.           1.99999982   2.18130894]
#  [  2.           2.99999974   2.21038079]
#  ...
#  [497.         497.99995614   2.60253513]
#  [498.         498.99995605   2.54987472]
#  [499.         499.99995596   2.58881546]]

# %%
#試しなので関係ない
import os
import MDAnalysis as mda
from MDAnalysis.analysis import rms
import numpy as np

def RMSD(output_file="rmsd.dat"):
    # 入力ファイルのパス
    psf_file_path = '/Users/teraimao/experiment/work/1885_work/gbsw_in/peptide_in.psf'
    dcd_file_path = '/Users/teraimao/experiment/work/1885_work/gbsw_in/gbsw_in.dcd'

    # 出力ディレクトリの確認と作成
    output_dir = os.path.dirname(output_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)  # ディレクトリが存在しない場合に作成
        print(f"Output directory created: {output_dir}")

    # ユニバースを作成 (構造ファイル + DCD)
    u = mda.Universe(psf_file_path, dcd_file_path)

    # 参照構造を作成 (最初のフレームを参照構造として扱う)
    ref = mda.Universe(psf_file_path,dcd_file_path)
    ref_atoms = ref.select_atoms("all")
    mobile_atoms = u.select_atoms("all")

    # RMSD 計算
    R = rms.RMSD(mobile_atoms, ref_atoms)
    R.run()

    # 結果を出力 (非推奨警告対応: R.results.rmsd を使用)
    data = R.results.rmsd  # numpy array: [frame, time(ps), RMSD(Å)]

    # 出力ファイルを保存
    np.savetxt(output_file, data, header="Frame Time(ps) RMSD(Å)", fmt="%8d %8.3f %8.3f")
    print(f"RMSD results saved to: {output_file}")
    print(data)

# 実行例
output_file_path = '/Users/teraimao/experiment/work/1885_work/gbsw_out/2rmsd.dat'
RMSD(output_file=output_file_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 #試しなので関係ない
#       2 import os
# ----> 3 import MDAnalysis as mda
#       4 from MDAnalysis.analysis import rms
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'MDAnalysis'

# %%
#主鎖と側鎖CβのRMSD別々に取得
import os
import MDAnalysis as mda
from MDAnalysis.analysis import rms
import numpy as np

def RMSD(output_file="rmsd_backbone_cb.dat"):
    # 入力ファイルのパス
    psf_file_path = '/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_out/peptide_out.psf'
    dcd_file_path = '/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_out/gbsw_out.dcd'

    # 出力ディレクトリの確認と作成
    output_dir = os.path.dirname(output_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)  # ディレクトリが存在しない場合に作成
        print(f"Output directory created: {output_dir}")

    # ユニバースを作成 (構造ファイル + DCD)
    u = mda.Universe(psf_file_path, dcd_file_path)

    # 参照構造を作成 (最初のフレームを参照構造として扱う)
    ref_frame = 0
    ref = mda.Universe('/Users/teraimao/experiment/work/0_18_35_K,N,S,Y,F_work/gbsw_out/peptide_out.psf',
                       '/Users/teraimao/experiment/work/0_18_35_K,N,S,Y,F_work/gbsw_out/gbsw_out.dcd')
    ref.trajectory[ref_frame]

    # 主鎖（バックボーン）の選択
    ref_atoms_backbone = ref.select_atoms("backbone")
    mobile_atoms_backbone = u.select_atoms("backbone")

    # 側鎖の Cβ の選択（グリシンを除外）
    ref_atoms_cb = ref.select_atoms("name CB and not resname GLY")
    mobile_atoms_cb = u.select_atoms("name CB and not resname GLY")

    # RMSD 計算 (バックボーン)
    R_backbone = rms.RMSD(mobile_atoms_backbone, ref_atoms_backbone)
    R_backbone.run()
    data_backbone = R_backbone.results.rmsd  # [frame, time(ps), RMSD(Å)]

    # RMSD 計算 (Cβ)
    R_cb = rms.RMSD(mobile_atoms_cb, ref_atoms_cb)
    R_cb.run()
    data_cb = R_cb.results.rmsd  # [frame, time(ps), RMSD(Å)]

    # 出力ファイルを保存
    np.savetxt(output_file.replace(".dat", "_backbone.dat"), data_backbone, header="Frame Time(ps) RMSD(Å)", fmt="%8d %8.3f %8.3f")
    np.savetxt(output_file.replace(".dat", "_cb.dat"), data_cb, header="Frame Time(ps) RMSD(Å)", fmt="%8d %8.3f %8.3f")

    print(f"Backbone RMSD results saved to: {output_file.replace('.dat', '_backbone.dat')}")
    print(f"CB RMSD results saved to: {output_file.replace('.dat', '_cb.dat')}")

# %%
# !pip install MDAnalysis
# Out:
# Requirement already satisfied: MDAnalysis in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (2.7.0)
# Requirement already satisfied: numpy<2.0,>=1.22.3 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (1.26.4)
# Requirement already satisfied: GridDataFormats>=0.4.0 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (1.0.2)
# Requirement already satisfied: mmtf-python>=1.0.0 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (1.1.3)
# Requirement already satisfied: joblib>=0.12 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (1.4.2)
# Requirement already satisfied: scipy>=1.5.0 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (1.13.1)
# Requirement already satisfied: matplotlib>=1.5.1 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (3.8.4)
# Requirement already satisfied: tqdm>=4.43.0 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (4.66.5)
# Requirement already satisfied: threadpoolctl in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (3.5.0)
# Requirement already satisfied: packaging in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (24.1)
# Requirement already satisfied: fasteners in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (0.19)
# Requirement already satisfied: mda-xdrlib in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from MDAnalysis) (0.2.0)
# Requirement already satisfied: mrcfile in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from GridDataFormats>=0.4.0->MDAnalysis) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from matplotlib>=1.5.1->MDAnalysis) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from matplotlib>=1.5.1->MDAnalysis) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from matplotlib>=1.5.1->MDAnalysis) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from matplotlib>=1.5.1->MDAnalysis) (1.4.4)
# Requirement already satisfied: pillow>=8 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from matplotlib>=1.5.1->MDAnalysis) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from matplotlib>=1.5.1->MDAnalysis) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from matplotlib>=1.5.1->MDAnalysis) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from matplotlib>=1.5.1->MDAnalysis) (6.4.0)
# Requirement already satisfied: msgpack>=1.0.0 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from mmtf-python>=1.0.0->MDAnalysis) (1.1.0)
# Requirement already satisfied: zipp>=3.1.0 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=1.5.1->MDAnalysis) (3.17.0)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=1.5.1->MDAnalysis) (1.16.0)

# %%
#import MDAnalysis as mda
#print(mda.__version__)
# Out:
# 2.8.0

# %%
#主鎖とCβのrmsd
import os
import MDAnalysis as mda
from MDAnalysis.analysis import rms
import numpy as np

def RMSD(output_file="rmsd_backbone_cb_combined.dat"):
    # 入力ファイルのパス
    psf_file_path = '/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_in/peptide_in.psf'
    dcd_file_path = '/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_in/gbsw_in.dcd'

    # 出力ディレクトリの確認と作成
    output_dir = os.path.dirname(output_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)  # ディレクトリが存在しない場合に作成
        print(f"Output directory created: {output_dir}")

    # ユニバースを作成 (構造ファイル + DCD)
    u = mda.Universe(psf_file_path, dcd_file_path)

    # 参照構造を作成 (最初のフレームを参照構造として扱う)
    ref_frame = 0
    ref = mda.Universe('/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_in/peptide_in.psf',
                       '/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/gbsw_in/gbsw_in.dcd')
    ref.trajectory[ref_frame]

    # 🔹 主鎖（バックボーン）と Cβ の両方を選択
    ref_atoms_combined = ref.select_atoms("backbone or (name CB and not resname GLY)")
    mobile_atoms_combined = u.select_atoms("backbone or (name CB and not resname GLY)")

    # 🔹 RMSD 計算
    R_combined = rms.RMSD(mobile_atoms_combined, ref_atoms_combined)
    R_combined.run()
    data_combined = R_combined.results.rmsd  # [frame, time(ps), RMSD(Å)]

    # 🔹 出力ファイルを保存（1 つのファイルに統合）
    np.savetxt(output_file, data_combined, header="Frame Time(ps) RMSD(Å)", fmt="%8d %8.3f %8.3f")

    print(f"Backbone + CB RMSD results saved to: {output_file}")

# 関数を実行

# %%
RMSD(output_file="/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/analysis/ana_gbsw_in/rmsd/rmsd_backbone_cb_combined.dat")
# Out:
# Backbone + CB RMSD results saved to: /Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/analysis/ana_gbsw_in/rmsd/rmsd_backbone_cb_combined.dat

# %% [markdown]
# ### RMSDの計算

# %%
pip install rdkit
# Out:
# Requirement already satisfied: rdkit in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (2024.9.5)
# Requirement already satisfied: numpy in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in ./opt/anaconda3/envs/python_3.9/lib/python3.9/site-packages (from rdkit) (10.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

# PDBファイルの読み込み
mol = Chem.MolFromPDBFile("/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/charmm/peptide.pdb", removeHs=False)

# TPSAの計算
if mol:
    tpsa = Descriptors.TPSA(mol)
    print(f"PDB構造のTPSA: {tpsa:.2f} Å²")
else:
    print("分子を読み込めませんでした。")
# Out:
# PDB構造のTPSA: 256.69 Å²

# %%
#in.sur.outのrmsd
import os
import MDAnalysis as mda
from MDAnalysis.analysis import rms
import numpy as np

def calculate_rmsd(value):
    peptide_positions = ["in", "sur", "out"]

    for pos in peptide_positions:
        # 🔹 入力ファイルのパス
        psf_file_path = f'/Users/teraimao/experiment/work/{value}_work/gbsw_{pos}/peptide_{pos}.psf'
        dcd_file_path = f'/Users/teraimao/experiment/work/{value}_work/gbsw_{pos}/gbsw_{pos}.dcd'

        # 🔹 出力ファイルのディレクトリとパス
        rmsd_dir = f'/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{pos}/rmsd'
        output_file = os.path.join(rmsd_dir, "rmsd_backbone_cb_combined.dat")
        average_dir = os.path.join(rmsd_dir, "average")  # 平均値保存用ディレクトリ
        average_file = os.path.join(average_dir, "result.txt")  # 平均 RMSD の保存ファイル

        # 🔹 出力ディレクトリが存在しない場合は作成
        os.makedirs(rmsd_dir, exist_ok=True)
        os.makedirs(average_dir, exist_ok=True)

        # 🔹 ユニバースを作成 (構造ファイル + DCD)
        try:
            u = mda.Universe(psf_file_path, dcd_file_path)
            ref = mda.Universe(psf_file_path, dcd_file_path)
        except Exception as e:
            print(f"Error loading files for {pos}: {e}")
            continue  # 次の `peptide_positions` へスキップ

        # 🔹 参照構造を作成 (最初のフレームを参照構造として扱う)
        ref.trajectory[0]

        # 🔹 主鎖（バックボーン）と Cβ の両方を選択
        ref_atoms_combined = ref.select_atoms("backbone or (name CB and not resname GLY)")
        mobile_atoms_combined = u.select_atoms("backbone or (name CB and not resname GLY)")

        # 🔹 RMSD 計算
        R_combined = rms.RMSD(mobile_atoms_combined, ref_atoms_combined)
        R_combined.run()
        data_combined = R_combined.results.rmsd  # [frame, time(ps), RMSD(Å)]

        # 🔹 出力ファイルを保存
        np.savetxt(output_file, data_combined, header="Frame Time(ps) RMSD(Å)", fmt="%8d %8.3f %8.3f")
        print(f"Backbone + CB RMSD results saved to: {output_file}")

        # 🔹 RMSD の平均値を計算
        rmsd_values = data_combined[:, 2]  # 3列目 (RMSD 値) を取得
        rmsd_mean = np.mean(rmsd_values)

        # 🔹 平均 RMSD を `result.txt` に保存
        with open(average_file, "w") as avg_file:
            avg_file.write(f"Average RMSD: {rmsd_mean:.3f} Å\n")

        print(f"Average RMSD saved to: {average_file}")

# 🔹 関数を実行
# calculate_rmsd("13_14_15_K,N,S,Y,F")  # `value` を指定して実行

# %%
def all_rmsd():
    #value = ["0_18_35_K,N,S,Y,F","13_14_15_K,N,S,Y,F","16_17_18_K,N,S,Y,F",
     #       "19_20_21_K,N,S,Y,F","1_2_3_K,N,S,Y,F","4_5_6_K,N,S,Y,F",
      #      "9_10_11_K,N,S,Y,F","7_8_12_K,N,S,Y,F","22_23_24_K,N,S,Y,F]
    value = ["G,L,G,F,P"]
    for value in value:
        calculate_rmsd(value)

# %%
all_rmsd()
# Out:
# Backbone + CB RMSD results saved to: /Users/teraimao/experiment/work/G,L,G,F,P_work/analysis/ana_gbsw_in/rmsd/rmsd_backbone_cb_combined.dat
# Average RMSD saved to: /Users/teraimao/experiment/work/G,L,G,F,P_work/analysis/ana_gbsw_in/rmsd/average/result.txt
# Backbone + CB RMSD results saved to: /Users/teraimao/experiment/work/G,L,G,F,P_work/analysis/ana_gbsw_sur/rmsd/rmsd_backbone_cb_combined.dat
# Average RMSD saved to: /Users/teraimao/experiment/work/G,L,G,F,P_work/analysis/ana_gbsw_sur/rmsd/average/result.txt
# Backbone + CB RMSD results saved to: /Users/teraimao/experiment/work/G,L,G,F,P_work/analysis/ana_gbsw_out/rmsd/rmsd_backbone_cb_combined.dat
# Average RMSD saved to: /Users/teraimao/experiment/work/G,L,G,F,P_work/analysis/ana_gbsw_out/rmsd/average/result.txt

# %% [markdown]
# ### 計算したrmsdを見る

# %%
import os

def read_rmsd_data(value):
    peptide_positions = ["in", "sur", "out"]
    all_data = {}  # 各 `pos` のデータを保存する辞書

    for pos in peptide_positions:
        file_path = f'/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{pos}/rmsd/average/result.txt'

        try:
            if not os.path.exists(file_path):
                print(f"Warning: File not found: {file_path}")
                continue  # ファイルがない場合はスキップ

            with open(file_path, "r") as file:
                lines = file.readlines()
                if not lines:
                    print(f"Warning: {file_path} is empty")
                    continue  # 空のファイルはスキップ

                # 🔹 `result.txt` の内容を解析
                first_line = lines[0].strip()
                rmsd_value = float(first_line.split(":")[-1].strip().split(" ")[0])  # 数値部分のみ取得
                all_data[pos] = rmsd_value  # 各 `pos` の平均 RMSD を保存

                print(f"Average {value} RMSD for {pos}: {rmsd_value} Å")

        except Exception as e:
            print(f"Error reading {file_path}: {e}")
            continue  # エラーがあっても次の `pos` へ進む

    return all_data  # 各 `pos` のデータを辞書で返す

# %%
def all_read_rmsd():
    #value = ["0_18_35_K,N,S,Y,F","13_14_15_K,N,S,Y,F","16_17_18_K,N,S,Y,F",
     #       "19_20_21_K,N,S,Y,F","1_2_3_K,N,S,Y,F","4_5_6_K,N,S,Y,F",
      #      "9_10_11_K,N,S,Y,F","7_8_12_K,N,S,Y,F","22_23_24_K,N,S,Y,F"]
    value = ["G,L,G,F,P"]
    for value in value:
        read_rmsd_data(value)

# %%
all_read_rmsd()
# Out:
# Average G,L,G,F,P RMSD for in: 0.62 Å
# Average G,L,G,F,P RMSD for sur: 0.924 Å
# Average G,L,G,F,P RMSD for out: 1.511 Å

# %% [markdown]
# ### 計算した水素結合を見る

# %%
def read_hbond_data(value):
    peptide_positions = ["in", "sur", "out"]
    all_data = {}  # 各 `pos` のデータを保存する辞書

    for pos in peptide_positions:
        file_path = f'/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{pos}/hbond/average/result.txt'

        try:
            if not os.path.exists(file_path):
                print(f"Warning: File not found: {file_path}")
                continue  # ファイルがない場合はスキップ

            with open(file_path, "r") as file:
                lines = file.readlines()
                if not lines:
                    print(f"Warning: {file_path} is empty")
                    continue  # 空のファイルはスキップ

                # 🔹 `result.txt` の内容を解析
                first_line = lines[0].strip()
                rmsd_value = float(first_line.split(":")[-1].strip().split(" ")[0])  # 数値部分のみ取得
                all_data[pos] = rmsd_value  # 各 `pos` の平均 RMSD を保存

                print(f"Average {value} hbond for {pos}: {rmsd_value} 個")

        except Exception as e:
            print(f"Error reading {file_path}: {e}")
            continue  # エラーがあっても次の `pos` へ進む

    return all_data  # 各 `pos` のデータを辞書で返す

# %%
def all_read_hbond():
    #value = ["0_18_35_K,N,S,Y,F","13_14_15_K,N,S,Y,F","16_17_18_K,N,S,Y,F",
     #       "19_20_21_K,N,S,Y,F","1_2_3_K,N,S,Y,F","4_5_6_K,N,S,Y,F",
      #      "9_10_11_K,N,S,Y,F","7_8_12_K,N,S,Y,F","22_23_24_K,N,S,Y,F"]
    value = ["G,L,G,F,P"]
    for value in value:
        read_hbond_data(value)

# %%
all_read_hbond()
# Out:
# Average G,L,G,F,P hbond for in: 0.891089 個
# Average G,L,G,F,P hbond for sur: 0.257426 個
# Average G,L,G,F,P hbond for out: 1.059406 個

# %% [markdown]
# ### 計算した溶媒和自由エネルギーを見る

# %%
def read_solv_data(value):
    peptide_positions = ["in", "sur", "out"]
    all_data = {}  # 各 `pos` のデータを保存する辞書

    for pos in peptide_positions:
        file_path = f'/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{pos}/solv_free_ener/average/result.txt'

        try:
            if not os.path.exists(file_path):
                print(f"Warning: File not found: {file_path}")
                continue  # ファイルがない場合はスキップ

            with open(file_path, "r") as file:
                lines = file.readlines()
                if not lines:
                    print(f"Warning: {file_path} is empty")
                    continue  # 空のファイルはスキップ

                # 🔹 `result.txt` の内容を解析
                first_line = lines[0].strip()
                rmsd_value = float(first_line.split(":")[-1].strip().split(" ")[0])  # 数値部分のみ取得
                all_data[pos] = rmsd_value  # 各 `pos` の平均 RMSD を保存

                print(f"Average {value} RMSD for {pos}: {rmsd_value} kcal/mol")

        except Exception as e:
            print(f"Error reading {file_path}: {e}")
            continue  # エラーがあっても次の `pos` へ進む

    return all_data  # 各 `pos` のデータを辞書で返す

# %%
def all_read_solv():
    #value = ["0_18_35_K,N,S,Y,F","13_14_15_K,N,S,Y,F","16_17_18_K,N,S,Y,F",
     #       "19_20_21_K,N,S,Y,F","1_2_3_K,N,S,Y,F","4_5_6_K,N,S,Y,F",
      #      "9_10_11_K,N,S,Y,F","7_8_12_K,N,S,Y,F","22_23_24_K,N,S,Y,F"]
    #value = ["G,L,G,F,P"]
    value = ["0_15_30_nK,N,S,Y,F","1_2_3_nK,N,S,Y,F","4_5_6_nK,N,S,Y,F",
               "7_8_9_nK,N,S,Y,F","10_11_12_nK,N,S,Y,F","13_14_16nK,N,S,Y,F",
               "17_18_19_nK,N,S,Y,F","20_21_22_nK,N,S,Y,F","23_24_25_nK,N,S,Y,F",
               "26_27_28_nK,N,S,Y,F","29_2_31_nK,N,S,Y,F", "0_15_30_nG,L,G,F,P",
               "1_2_3_nG,L,G,F,P","4_5_6_nG,L,G,F,P","7_8_9_nG,L,G,F,P",
               "10_11_12_nG,L,G,F,P","13_14_16nG,L,G,F,P","17_18_19_nG,L,G,F,P",
               "20_21_22_nG,L,G,F,P","23_24_25_nG,L,G,F,P","26_27_28_nG,L,G,F,P",
               "29_20_31_nG,L,G,F,P"]
    for value in value:
        read_solv_data(value)

# %%
all_read_solv()
# Out:
# Average 0_15_30_nK,N,S,Y,F RMSD for in: -52.493523 kcal/mol
# Average 0_15_30_nK,N,S,Y,F RMSD for sur: -159.719445 kcal/mol
# Average 0_15_30_nK,N,S,Y,F RMSD for out: -132.734677 kcal/mol
# Average 1_2_3_nK,N,S,Y,F RMSD for in: -33.158731 kcal/mol
# Average 1_2_3_nK,N,S,Y,F RMSD for sur: -65.167102 kcal/mol
# Average 1_2_3_nK,N,S,Y,F RMSD for out: -75.409238 kcal/mol
# Average 4_5_6_nK,N,S,Y,F RMSD for in: -69.84497 kcal/mol
# Average 4_5_6_nK,N,S,Y,F RMSD for sur: -79.312083 kcal/mol
# Average 4_5_6_nK,N,S,Y,F RMSD for out: -82.114696 kcal/mol
# Average 7_8_9_nK,N,S,Y,F RMSD for in: -96.192359 kcal/mol
# Average 7_8_9_nK,N,S,Y,F RMSD for sur: -99.980987 kcal/mol
# Average 7_8_9_nK,N,S,Y,F RMSD for out: -100.13023 kcal/mol
# Average 10_11_12_nK,N,S,Y,F RMSD for in: -99.787597 kcal/mol
# Average 10_11_12_nK,N,S,Y,F RMSD for sur: -109.384445 kcal/mol
# Average 10_11_12_nK,N,S,Y,F RMSD for out: -117.51257 kcal/mol
# Average 13_14_16nK,N,S,Y,F RMSD for in: -127.874535 kcal/mol
# Average 13_14_16nK,N,S,Y,F RMSD for sur: -137.783751 kcal/mol
# Average 13_14_16nK,N,S,Y,F RMSD for out: -129.831965 kcal/mol
# Average 17_18_19_nK,N,S,Y,F RMSD for in: -138.982884 kcal/mol
# Average 17_18_19_nK,N,S,Y,F RMSD for sur: -138.767504 kcal/mol
# Average 17_18_19_nK,N,S,Y,F RMSD for out: -127.838717 kcal/mol
# Average 20_21_22_nK,N,S,Y,F RMSD for in: -131.812132 kcal/mol
# Average 20_21_22_nK,N,S,Y,F RMSD for sur: -140.6736 kcal/mol
# Average 20_21_22_nK,N,S,Y,F RMSD for out: -148.286973 kcal/mol
# Average 23_24_25_nK,N,S,Y,F RMSD for in: -134.48477 kcal/mol
# Average 23_24_25_nK,N,S,Y,F RMSD for sur: -145.988584 kcal/mol
# Average 23_24_25_nK,N,S,Y,F RMSD for out: -137.449792 kcal/mol
# Average 26_27_28_nK,N,S,Y,F RMSD for in: -106.312004 kcal/mol
# Average 26_27_28_nK,N,S,Y,F RMSD for sur: -132.638603 kcal/mol
# Average 26_27_28_nK,N,S,Y,F RMSD for out: -169.284454 kcal/mol
# Average 29_2_31_nK,N,S,Y,F RMSD for in: -110.559191 kcal/mol
# Average 29_2_31_nK,N,S,Y,F RMSD for sur: -32.847884 kcal/mol
# Average 29_2_31_nK,N,S,Y,F RMSD for out: -167.84776 kcal/mol
# Average 0_15_30_nG,L,G,F,P RMSD for in: -1.629171 kcal/mol
# Average 0_15_30_nG,L,G,F,P RMSD for sur: -32.70774 kcal/mol
# Average 0_15_30_nG,L,G,F,P RMSD for out: -46.297664 kcal/mol
# Average 1_2_3_nG,L,G,F,P RMSD for in: -1.15487 kcal/mol
# Average 1_2_3_nG,L,G,F,P RMSD for sur: -0.96884 kcal/mol
# Average 1_2_3_nG,L,G,F,P RMSD for out: -1.321075 kcal/mol
# Average 4_5_6_nG,L,G,F,P RMSD for in: -1.390723 kcal/mol
# Average 4_5_6_nG,L,G,F,P RMSD for sur: -1.177783 kcal/mol
# Average 4_5_6_nG,L,G,F,P RMSD for out: -1.087588 kcal/mol
# Average 7_8_9_nG,L,G,F,P RMSD for in: -0.715781 kcal/mol
# Average 7_8_9_nG,L,G,F,P RMSD for sur: -1.540376 kcal/mol
# Average 7_8_9_nG,L,G,F,P RMSD for out: -3.449176 kcal/mol
# Average 10_11_12_nG,L,G,F,P RMSD for in: -5.086492 kcal/mol
# Average 10_11_12_nG,L,G,F,P RMSD for sur: -7.614864 kcal/mol
# Average 10_11_12_nG,L,G,F,P RMSD for out: -16.751814 kcal/mol
# Average 13_14_16nG,L,G,F,P RMSD for in: -29.567247 kcal/mol
# Average 13_14_16nG,L,G,F,P RMSD for sur: -34.769848 kcal/mol
# Average 13_14_16nG,L,G,F,P RMSD for out: -42.104572 kcal/mol
# Average 17_18_19_nG,L,G,F,P RMSD for in: -24.958237 kcal/mol
# Average 17_18_19_nG,L,G,F,P RMSD for sur: -46.569671 kcal/mol
# Average 17_18_19_nG,L,G,F,P RMSD for out: -41.903677 kcal/mol
# Average 20_21_22_nG,L,G,F,P RMSD for in: -35.007672 kcal/mol
# Average 20_21_22_nG,L,G,F,P RMSD for sur: -38.224272 kcal/mol
# Average 20_21_22_nG,L,G,F,P RMSD for out: -29.951568 kcal/mol
# Average 23_24_25_nG,L,G,F,P RMSD for in: -29.965091 kcal/mol
# Average 23_24_25_nG,L,G,F,P RMSD for sur: -48.910003 kcal/mol
# Average 23_24_25_nG,L,G,F,P RMSD for out: -31.259927 kcal/mol
# Average 26_27_28_nG,L,G,F,P RMSD for in: -37.868562 kcal/mol
# Average 26_27_28_nG,L,G,F,P RMSD for sur: -40.643558 kcal/mol
# Average 26_27_28_nG,L,G,F,P RMSD for out: -42.01141 kcal/mol
# Average 29_20_31_nG,L,G,F,P RMSD for in: -29.635642 kcal/mol
# Average 29_20_31_nG,L,G,F,P RMSD for sur: -37.381524 kcal/mol
# Average 29_20_31_nG,L,G,F,P RMSD for out: -48.194469 kcal/mol

# %% [markdown]
# ### 計算した表面積をみる

# %%
import os

def read_surf_data(value):
    peptide_positions = ["in", "sur", "out"]
    all_data = {}  # 各 `pos` のデータを保存する辞書

    for pos in peptide_positions:
        file_path = f'/Users/teraimao/experiment/work/{value}_work/analysis/ana_gbsw_{pos}/surf_area/average/result.txt'

        try:
            if not os.path.exists(file_path):
                print(f"Warning: File not found: {file_path}")
                continue  # ファイルがない場合はスキップ

            with open(file_path, "r") as file:
                lines = file.readlines()
                if not lines:
                    print(f"Warning: {file_path} is empty")
                    continue  # 空のファイルはスキップ

                # 🔹 各 `pos` のデータを保存する辞書
                pos_data = {}

                for line in lines:
                    line = line.strip()
                    if line.startswith("Column"):
                        parts = line.split(":")
                        if len(parts) == 2:
                            column_name = parts[0].strip()
                            value_str = parts[1].strip()
                            try:
                                value_float = float(value_str)
                                pos_data[column_name] = value_float
                            except ValueError:
                                print(f"Warning: Could not convert {value_str} to float in {file_path}")

                all_data[pos] = pos_data  # 各 `pos` のデータを保存

                print(f"{value} Average surface data for {pos}: {pos_data}")

        except Exception as e:
            print(f"Error reading {file_path}: {e}")
            continue  # エラーがあっても次の `pos` へ進む

    return all_data  # 各 `pos` のデータを辞書で返す

# %%
def all_read_surf():
    #value = ["0_18_35_K,N,S,Y,F","13_14_15_K,N,S,Y,F","16_17_18_K,N,S,Y,F",
     #       "19_20_21_K,N,S,Y,F","1_2_3_K,N,S,Y,F","4_5_6_K,N,S,Y,F",
      #      "9_10_11_K,N,S,Y,F","7_8_12_K,N,S,Y,F","22_23_24_K,N,S,Y,F"]
    #value = ["G,L,G,F,P"]
    value = ["0_15_30_nK,N,S,Y,F","1_2_3_nK,N,S,Y,F","4_5_6_nK,N,S,Y,F",
               "7_8_9_nK,N,S,Y,F","10_11_12_nK,N,S,Y,F","13_14_16nK,N,S,Y,F",
               "17_18_19_nK,N,S,Y,F","20_21_22_nK,N,S,Y,F","23_24_25_nK,N,S,Y,F",
               "26_27_28_nK,N,S,Y,F","29_2_31_nK,N,S,Y,F", "0_15_30_nG,L,G,F,P",
               "1_2_3_nG,L,G,F,P","4_5_6_nG,L,G,F,P","7_8_9_nG,L,G,F,P",
               "10_11_12_nG,L,G,F,P","13_14_16nG,L,G,F,P","17_18_19_nG,L,G,F,P",
               "20_21_22_nG,L,G,F,P","23_24_25_nG,L,G,F,P","26_27_28_nG,L,G,F,P",
               "29_20_31_nG,L,G,F,P"]
    for value in value:
        read_surf_data(value)

# %%
all_read_surf()
# Out:
# 0_15_30_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 891.145876, 'Column 3 average': 770.754015}
# 0_15_30_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 901.079636, 'Column 3 average': 758.285238}
# 0_15_30_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 871.150878, 'Column 3 average': 764.267315}
# 1_2_3_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 886.975116, 'Column 3 average': 713.434982}
# 1_2_3_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 909.611323, 'Column 3 average': 786.896239}
# 1_2_3_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 895.965428, 'Column 3 average': 769.02102}
# 4_5_6_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 909.364858, 'Column 3 average': 785.172225}
# 4_5_6_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 902.358654, 'Column 3 average': 773.519717}
# 4_5_6_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 902.413368, 'Column 3 average': 784.401951}
# 7_8_9_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 902.001243, 'Column 3 average': 770.092002}
# 7_8_9_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 904.102006, 'Column 3 average': 788.918144}
# 7_8_9_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 878.392061, 'Column 3 average': 777.821714}
# 10_11_12_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 894.167439, 'Column 3 average': 783.920945}
# 10_11_12_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 877.31442, 'Column 3 average': 761.59999}
# 10_11_12_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 886.932499, 'Column 3 average': 746.859516}
# 13_14_16nK,N,S,Y,F Average surface data for in: {'Column 2 average': 887.269499, 'Column 3 average': 717.298277}
# 13_14_16nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 899.597958, 'Column 3 average': 766.106971}
# 13_14_16nK,N,S,Y,F Average surface data for out: {'Column 2 average': 884.31037, 'Column 3 average': 746.193343}
# 17_18_19_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 901.900138, 'Column 3 average': 769.294059}
# 17_18_19_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 896.761558, 'Column 3 average': 751.327465}
# 17_18_19_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 902.283822, 'Column 3 average': 779.478316}
# 20_21_22_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 909.89773, 'Column 3 average': 737.831399}
# 20_21_22_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 891.226501, 'Column 3 average': 775.158289}
# 20_21_22_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 916.444929, 'Column 3 average': 752.557083}
# 23_24_25_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 836.557312, 'Column 3 average': 743.621132}
# 23_24_25_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 881.522838, 'Column 3 average': 759.345967}
# 23_24_25_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 891.158878, 'Column 3 average': 775.011349}
# 26_27_28_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 862.03207, 'Column 3 average': 725.236105}
# 26_27_28_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 847.073328, 'Column 3 average': 784.29607}
# 26_27_28_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 896.174416, 'Column 3 average': 778.574071}
# 29_2_31_nK,N,S,Y,F Average surface data for in: {'Column 2 average': 867.055068, 'Column 3 average': 734.026839}
# 29_2_31_nK,N,S,Y,F Average surface data for sur: {'Column 2 average': 879.178618, 'Column 3 average': 700.852007}
# 29_2_31_nK,N,S,Y,F Average surface data for out: {'Column 2 average': 887.125752, 'Column 3 average': 760.490809}
# 0_15_30_nG,L,G,F,P Average surface data for in: {'Column 2 average': 718.766987, 'Column 3 average': 411.555426}
# 0_15_30_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 704.143107, 'Column 3 average': 424.954966}
# 0_15_30_nG,L,G,F,P Average surface data for out: {'Column 2 average': 722.915104, 'Column 3 average': 420.488711}
# 1_2_3_nG,L,G,F,P Average surface data for in: {'Column 2 average': 724.369716, 'Column 3 average': 414.302134}
# 1_2_3_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 728.693137, 'Column 3 average': 418.791022}
# 1_2_3_nG,L,G,F,P Average surface data for out: {'Column 2 average': 725.934228, 'Column 3 average': 410.638407}
# 4_5_6_nG,L,G,F,P Average surface data for in: {'Column 2 average': 729.292589, 'Column 3 average': 414.49278}
# 4_5_6_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 724.385461, 'Column 3 average': 414.36224}
# 4_5_6_nG,L,G,F,P Average surface data for out: {'Column 2 average': 747.554436, 'Column 3 average': 422.565871}
# 7_8_9_nG,L,G,F,P Average surface data for in: {'Column 2 average': 745.170597, 'Column 3 average': 416.522961}
# 7_8_9_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 747.725067, 'Column 3 average': 423.570712}
# 7_8_9_nG,L,G,F,P Average surface data for out: {'Column 2 average': 729.255146, 'Column 3 average': 421.201029}
# 10_11_12_nG,L,G,F,P Average surface data for in: {'Column 2 average': 729.964153, 'Column 3 average': 419.951694}
# 10_11_12_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 735.111935, 'Column 3 average': 419.010272}
# 10_11_12_nG,L,G,F,P Average surface data for out: {'Column 2 average': 744.551316, 'Column 3 average': 414.163339}
# 13_14_16nG,L,G,F,P Average surface data for in: {'Column 2 average': 748.855278, 'Column 3 average': 417.923963}
# 13_14_16nG,L,G,F,P Average surface data for sur: {'Column 2 average': 748.834586, 'Column 3 average': 418.023003}
# 13_14_16nG,L,G,F,P Average surface data for out: {'Column 2 average': 724.353085, 'Column 3 average': 419.33467}
# 17_18_19_nG,L,G,F,P Average surface data for in: {'Column 2 average': 734.011178, 'Column 3 average': 418.934924}
# 17_18_19_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 747.827756, 'Column 3 average': 419.94555}
# 17_18_19_nG,L,G,F,P Average surface data for out: {'Column 2 average': 706.077518, 'Column 3 average': 425.691074}
# 20_21_22_nG,L,G,F,P Average surface data for in: {'Column 2 average': 707.448788, 'Column 3 average': 434.182008}
# 20_21_22_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 718.115268, 'Column 3 average': 423.012108}
# 20_21_22_nG,L,G,F,P Average surface data for out: {'Column 2 average': 688.955764, 'Column 3 average': 434.608965}
# 23_24_25_nG,L,G,F,P Average surface data for in: {'Column 2 average': 690.608263, 'Column 3 average': 436.048569}
# 23_24_25_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 751.946195, 'Column 3 average': 419.739026}
# 23_24_25_nG,L,G,F,P Average surface data for out: {'Column 2 average': 682.218866, 'Column 3 average': 437.858886}
# 26_27_28_nG,L,G,F,P Average surface data for in: {'Column 2 average': 682.501334, 'Column 3 average': 427.918086}
# 26_27_28_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 691.006343, 'Column 3 average': 414.292386}
# 26_27_28_nG,L,G,F,P Average surface data for out: {'Column 2 average': 688.706561, 'Column 3 average': 414.420554}
# 29_20_31_nG,L,G,F,P Average surface data for in: {'Column 2 average': 690.488054, 'Column 3 average': 434.150021}
# 29_20_31_nG,L,G,F,P Average surface data for sur: {'Column 2 average': 716.963798, 'Column 3 average': 429.508265}
# 29_20_31_nG,L,G,F,P Average surface data for out: {'Column 2 average': 752.931983, 'Column 3 average': 419.177559}

# %%
１番目のデータしか出ないので直さないと

# %%
cd 0_15_30_nK,N,S,Y,F/
