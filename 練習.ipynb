# %% [markdown]
# ### 機能

# %%
a = np.arange(1,5)
a
# Out:
# array([1, 2, 3, 4])

# %%
c = a.reshape(2,-1)
c
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
v = np.array([1,2,3,6,7,9,4,3,5]).reshape(3,-1)
v
# Out:
# array([[1, 2, 3],
#        [6, 7, 9],
#        [4, 3, 5]])

# %%
print(np.max(v,axis=0))
print(np.max(v,axis=1))
# Out:
# [6 7 9]
# [3 9 5]

# %%
print(v[0,2])
print(v[[1,2],0])
# Out:
# 3
# [6 4]

# %%
v
# Out:
# array([[1, 2, 3],
#        [6, 7, 9],
#        [4, 3, 5]])

# %%
idx=np.ix_([0,2],[1,2])
print(v[idx])
# Out:
# [[2 3]
#  [3 5]]

# %%
a = np.arange(4)
a
# Out:
# array([0, 1, 2, 3])

# %%
idx = [True, False, True, True]
a[idx]
# Out:
# array([0, 2, 3])

# %%
#内積
a = np.array([0,2,4])
b = np.array([5,7,9])
np.dot(a,b)
# Out:
# 50

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import numpy.random as random

# %%
series = Series([1,2,3,4,5])
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
i = Series([1,2,3,4],
          index =['a','b','c','d'])
i
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
#要素
print(i.values)
#インデックス
print(i.index)
# Out:
# [1 2 3 4]
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data = {'ID':['100','101','102','103','104'],
        'City':['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
        'Birth_year':[1990,1989,1992,1997,1982],
        'Name':['Hiroshi','Akiko','Yuki','Satoru','Steve']}

df = DataFrame(data)
print(df)
# Out:
#     ID      City  Birth_year     Name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982    Steve

# %%
#右はインデックス、真ん中が要素（values)、上はコラム(columns)

# %%
df.head()
# Out:
#     ID      City  Birth_year     Name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982    Steve

# %%
df_2 = DataFrame(data, index=['a','b','c','d','e'])
df_2
# Out:
#     ID      City  Birth_year     Name
# a  100     Tokyo        1990  Hiroshi
# b  101     Osaka        1989    Akiko
# c  102     Kyoto        1992     Yuki
# d  103  Hokkaido        1997   Satoru
# e  104     Tokyo        1982    Steve

# %%
print(df_2.index)
print(df_2.values)
print(df_2.columns)
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# [['100' 'Tokyo' 1990 'Hiroshi']
#  ['101' 'Osaka' 1989 'Akiko']
#  ['102' 'Kyoto' 1992 'Yuki']
#  ['103' 'Hokkaido' 1997 'Satoru']
#  ['104' 'Tokyo' 1982 'Steve']]
# Index(['ID', 'City', 'Birth_year', 'Name'], dtype='object')

# %%
pd.set_option('display.max_columns',50)
pd.set_option('display.max_rows', 50)

# %%
#web上に公開されているzip形式のファイルをダウンロード
import requests, zipfile
from io import StringIO
import io

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00320/student.zip'
#データをページから取ってくる
r = requests.get(url, stream=True)
#zipファイルを読み書きできるように展開
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
stu_data_math = pd.read_csv('student-mat.csv', sep =';')
stu_data_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#pd.read_csv(ファイル名)でDataFrame形式で、読み込まれる
#pd.read_csv(ファイル名, sep=';')で区切りを：から；にできる

# %%
stu_data_math.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
#  19  nursery     395 non-null    object
#  20  higher      395 non-null    object
#  21  internet    395 non-null    object
#  22  romantic    395 non-null    object
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 102.0+ KB

# %%
stu_data_math.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
df
# Out:
#     ID      City  Birth_year     Name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982    Steve

# %%
print(df['Birth_year'])
print(df.Birth_year)
#どっちでもいい
# Out:
# 0    1990
# 1    1989
# 2    1992
# 3    1997
# 4    1982
# Name: Birth_year, dtype: int64
# 0    1990
# 1    1989
# 2    1992
# 3    1997
# 4    1982
# Name: Birth_year, dtype: int64

# %%
print(df[['City','Birth_year']])
# Out:
#        City  Birth_year
# 0     Tokyo        1990
# 1     Osaka        1989
# 2     Kyoto        1992
# 3  Hokkaido        1997
# 4     Tokyo        1982

# %%
df
# Out:
#     ID      City  Birth_year     Name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982    Steve

# %%
df['Score']=np.arange(5)*10
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        1990  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
df[0:3]
# Out:
#     ID   City  Birth_year     Name  Score
# 0  100  Tokyo        1990  Hiroshi      0
# 1  101  Osaka        1989    Akiko     10
# 2  102  Kyoto        1992     Yuki     20

# %%
df.T['ID':'Name']
# Out:
#                   0      1      2         3      4
# ID              100    101    102       103    104
# City          Tokyo  Osaka  Kyoto  Hokkaido  Tokyo
# Birth_year     1990   1989   1992      1997   1982
# Name        Hiroshi  Akiko   Yuki    Satoru  Steve

# %%
#行名の指定
print(df.loc[0])
print(df.loc[0:2])
# Out:
# ID                100
# City            Tokyo
# Birth_year       1990
# Name          Hiroshi
# Score               0
# Name: 0, dtype: object
#     ID   City  Birth_year     Name  Score
# 0  100  Tokyo        1990  Hiroshi      0
# 1  101  Osaka        1989    Akiko     10
# 2  102  Kyoto        1992     Yuki     20

# %%
print(df.loc[:,'City'])
# Out:
# 0       Tokyo
# 1       Osaka
# 2       Kyoto
# 3    Hokkaido
# 4       Tokyo
# Name: City, dtype: object

# %%
df.loc[:,['Birth_year','Name']]
# Out:
#    Birth_year     Name
# 0        1990  Hiroshi
# 1        1989    Akiko
# 2        1992     Yuki
# 3        1997   Satoru
# 4        1982    Steve

# %%
df.loc[1,['Birth_year','Score']]
# Out:
# Birth_year    1989
# Score           10
# Name: 1, dtype: object

# %%
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        1990  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
print(df.iloc[0:4,[0,2]])
print(df.iloc[0:2,2:4])
print(df.iloc[0,2])
# Out:
#     ID  Birth_year
# 0  100        1990
# 1  101        1989
# 2  102        1992
# 3  103        1997
#    Birth_year     Name
# 0        1990  Hiroshi
# 1        1989    Akiko
# 1990

# %%
print(df.at[0,'ID'])
# Out:
# 100

# %%
print(df.iat[0,2])
# Out:
# 1990

# %%
df.at[0,'Birth_year']=2000
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        2000  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
import numpy as np
import numpy.random as random
import pandas as pd
from pandas import Series, DataFrame

# %%
series = Series([1,1,2,3,5,8,13])
print(series)
# Out:
# 0     1
# 1     1
# 2     2
# 3     3
# 4     5
# 5     8
# 6    13
# dtype: int64

# %%
series_i = Series(
    [1,1,2,3,5,8,13],
    index=['a', 'b', 'c', 'd', 'e', 'f','g'])
series_i
# Out:
# a     1
# b     1
# c     2
# d     3
# e     5
# f     8
# g    13
# dtype: int64

# %%
print(series_i.index)
print(series_i.values)
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')
# [ 1  1  2  3  5  8 13]

# %%
import requests, zipfile
from io import StringIO
import io

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00320/student.zip'

r = requests.get(url , stream=True)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
#tudent_data_math = pd.read_csv('ファイル名')
student_data_math = pd.read_csv('student-mat.csv',sep = ';')
student_data_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data = {'ID':['100','101','102','103','104'],
            'City':['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
            'Birth_year':[1990,1989,1992,1997,1982],
            'Name':['Hiroshi','Akiko','Yuki','Satoru','Steve']}

df = DataFrame(data)

print(df)
# Out:
#     ID      City  Birth_year     Name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982    Steve

# %%
print(df[['City','Name']])
print(df[['ID','Birth_year']])
# Out:
#        City     Name
# 0     Tokyo  Hiroshi
# 1     Osaka    Akiko
# 2     Kyoto     Yuki
# 3  Hokkaido   Satoru
# 4     Tokyo    Steve
#     ID  Birth_year
# 0  100        1990
# 1  101        1989
# 2  102        1992
# 3  103        1997
# 4  104        1982

# %%
print(df.loc[1:3,['Name','ID']])
print(df.iloc[1:3,[2,3]])
# Out:
#      Name   ID
# 1   Akiko  101
# 2    Yuki  102
# 3  Satoru  103
#    Birth_year   Name
# 1        1989  Akiko
# 2        1992   Yuki

# %%
df['Score']=np.arange(5)*10
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        1990  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
df[1:2]
# Out:
#     ID   City  Birth_year   Name  Score
# 1  101  Osaka        1989  Akiko     10

# %%
df.loc[0:2,['Name']]
# Out:
#       Name
# 0  Hiroshi
# 1    Akiko
# 2     Yuki

# %%
df.at[1,'ID']
# Out:
# '101'

# %%
df.iat[0,3]
# Out:
# 'Hiroshi'

# %%
df.at[0,'Birth_year']=2000
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        2000  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
#条件
df[df['Name']=='Akiko']
# Out:
#     ID   City  Birth_year   Name
# 1  101  Tokyo        1989  Akiko

# %%
print(df['City']=='Tokyo')
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: City, dtype: bool

# %%
df['Score']=np.arange(5)*10
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        1990  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
print(df['City']=='Tokyo')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: City, dtype: bool

# %%
df[(df['Birth_year'] >=1990) & (df['Birth_year']<=1995)]
# Out:
#     ID   City  Birth_year     Name  Score
# 0  100  Tokyo        1990  Hiroshi      0
# 2  102  Kyoto        1992     Yuki     20

# %%
# .isin　または
df[df['City'].isin(['Tokyo','Osaka'])]
# Out:
#     ID   City  Birth_year     Name  Score
# 0  100  Tokyo        1990  Hiroshi      0
# 1  101  Osaka        1989    Akiko     10
# 4  104  Tokyo        1982    Steve     40

# %%
df[df['Birth_year'].isin([1990,1997])]
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        1990  Hiroshi      0
# 3  103  Hokkaido        1997   Satoru     30

# %%
#または|
df[(df['City']=='Tokyo')|(df['Name']=='Hiroshi')]
# Out:
#     ID   City  Birth_year     Name  Score
# 0  100  Tokyo        1990  Hiroshi      0
# 4  104  Tokyo        1982    Steve     40

# %%
data2 = {
    'ID':['100','101','102','103','104'],
    'City':['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'Birth_year':[1990,1989,1992,1997,1982],
    'Name':['Hiroshi','Akiko','Yuki','Satoru','Steve']
}

df_i2 = DataFrame(data2, index=['e','b','a','d','c'])
df_i2
# Out:
#     ID      City  Birth_year     Name
# e  100     Tokyo        1990  Hiroshi
# b  101     Osaka        1989    Akiko
# a  102     Kyoto        1992     Yuki
# d  103  Hokkaido        1997   Satoru
# c  104     Tokyo        1982    Steve

# %%
#indexでソートする(並べ替え）
df_i2.sort_index()
# Out:
#     ID      City  Birth_year     Name
# a  102     Kyoto        1992     Yuki
# b  101     Osaka        1989    Akiko
# c  104     Tokyo        1982    Steve
# d  103  Hokkaido        1997   Satoru
# e  100     Tokyo        1990  Hiroshi

# %%
#値によるソート
df_i2.sort_values(by='Birth_year')
# Out:
#     ID      City  Birth_year     Name
# c  104     Tokyo        1982    Steve
# b  101     Osaka        1989    Akiko
# e  100     Tokyo        1990  Hiroshi
# a  102     Kyoto        1992     Yuki
# d  103  Hokkaido        1997   Satoru

# %%
df_i2.sort_values(by='Birth_year',ascending=False)
# Out:
#     ID      City  Birth_year     Name
# d  103  Hokkaido        1997   Satoru
# a  102     Kyoto        1992     Yuki
# e  100     Tokyo        1990  Hiroshi
# b  101     Osaka        1989    Akiko
# c  104     Tokyo        1982    Steve

# %%
#アルファベット
df_i2.sort_values(by='Name')
# Out:
#     ID      City  Birth_year     Name
# b  101     Osaka        1989    Akiko
# e  100     Tokyo        1990  Hiroshi
# d  103  Hokkaido        1997   Satoru
# c  104     Tokyo        1982    Steve
# a  102     Kyoto        1992     Yuki

# %%
#値(values)があるかどうか
df['City'].isin(['Tokyo'])
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: City, dtype: bool

# %%
df_i2['Name']=np.nan
df_i2.isnull()
# Out:
#       ID   City  Birth_year  Name
# e  False  False       False  True
# b  False  False       False  True
# a  False  False       False  True
# d  False  False       False  True
# c  False  False       False  True

# %%
df.isin(['Osaka'])
# Out:
#       ID   City  Birth_year   Name  Score
# 0  False  False       False  False  False
# 1  False   True       False  False  False
# 2  False  False       False  False  False
# 3  False  False       False  False  False
# 4  False  False       False  False  False

# %%
df_i2.isnull()
# Out:
#       ID   City  Birth_year  Name
# e  False  False       False  True
# b  False  False       False  True
# a  False  False       False  True
# d  False  False       False  True
# c  False  False       False  True

# %%
#nullを判定して、合計する
df_i2.isnull().sum()
# Out:
# ID            0
# City          0
# Birth_year    0
# Name          5
# dtype: int64

# %%
#データの結合
data1 = {
    'id': ['100', '101', '102', '103', '104', '106', '108', '110', '111',' 113'],
    'city': ['Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo', 'Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo'],
    'birth_year': [1990, 1989, 1992, 1997, 1982, 1991, 1988, 1990, 1995, 1981],
    'name': ['Hiroshi', 'Akiko', 'Yuki', 'Satoru', 'Steeve', 'Mituru', 'Aoi', 'Tarou', 'Suguru','Mitsuo']
}

df1 = DataFrame(data1)
df1
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo

# %%
data2 = {
    'id': ['100', '101', '102', '105', '107'],
    'math': [50, 43, 33, 76, 98],
    'english': [90, 30, 20, 50, 30],
    'sex': ['M','F','F','M','M'],
    'index_num': [0, 1, 2, 3, 4]
}
df2 = DataFrame(data2)
df2
# Out:
#     id  math  english sex  index_num
# 0  100    50       90   M          0
# 1  101    43       30   F          1
# 2  102    33       20   F          2
# 3  105    76       50   M          3
# 4  107    98       30   M          4

# %%
#内部結合：両方に共通するキーがあるとき結合
#左外部結合：左側にあるデータのキーがあるときに結合する
#右外部結合：右側にあるキーに合わせて結合
#完全外部結合：

# %%
#内部結合
pd.merge(df1,df2)
# Out:
#     id   city  birth_year     name  math  english sex  index_num
# 0  100  Tokyo        1990  Hiroshi    50       90   M          0
# 1  101  Osaka        1989    Akiko    43       30   F          1
# 2  102  Kyoto        1992     Yuki    33       20   F          2

# %%
pd.merge(df1,df2,on= 'id')
# Out:
#     id   city  birth_year     name  math  english sex  index_num
# 0  100  Tokyo        1990  Hiroshi    50       90   M          0
# 1  101  Osaka        1989    Akiko    43       30   F          1
# 2  102  Kyoto        1992     Yuki    33       20   F          2

# %%
df1
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo

# %%
df2
# Out:
#     id  math  english sex  index_num
# 0  100    50       90   M          0
# 1  101    43       30   F          1
# 2  102    33       20   F          2
# 3  105    76       50   M          3
# 4  107    98       30   M          4

# %%
pd.merge(df1,df2,left_index=True,right_on='index_num')
# Out:
#   id_x      city  birth_year     name id_y  math  english sex  index_num
# 0  100     Tokyo        1990  Hiroshi  100    50       90   M          0
# 1  101     Osaka        1989    Akiko  101    43       30   F          1
# 2  102     Kyoto        1992     Yuki  102    33       20   F          2
# 3  103  Hokkaido        1997   Satoru  105    76       50   M          3
# 4  104     Tokyo        1982   Steeve  107    98       30   M          4

# %%
#左のデータのインデックスと、右のindex_numのvaluesを比較して一致しているものを結合する
pd.merge(df1,df2,left_index=True,right_on='index_num')
# Out:
#   id_x      city  birth_year     name id_y  math  english sex  index_num
# 0  100     Tokyo        1990  Hiroshi  100    50       90   M          0
# 1  101     Osaka        1989    Akiko  101    43       30   F          1
# 2  102     Kyoto        1992     Yuki  102    33       20   F          2
# 3  103  Hokkaido        1997   Satoru  105    76       50   M          3
# 4  104     Tokyo        1982   Steeve  107    98       30   M          4

# %%
pd.merge(df1,df2,left_index=True,right_on='index_num',suffixes=('_1','_2'))
# Out:
#   id_1      city  birth_year     name id_2  math  english sex  index_num
# 0  100     Tokyo        1990  Hiroshi  100    50       90   M          0
# 1  101     Osaka        1989    Akiko  101    43       30   F          1
# 2  102     Kyoto        1992     Yuki  102    33       20   F          2
# 3  103  Hokkaido        1997   Satoru  105    76       50   M          3
# 4  104     Tokyo        1982   Steeve  107    98       30   M          4

# %%
df1
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo

# %%
df2
# Out:
#     id  math  english sex  index_num
# 0  100    50       90   M          0
# 1  101    43       30   F          1
# 2  102    33       20   F          2
# 3  105    76       50   M          3
# 4  107    98       30   M          4

# %%
pd.merge(df1,df2,how='left')
# Out:
#      id      city  birth_year     name  math  english  sex  index_num
# 0   100     Tokyo        1990  Hiroshi  50.0     90.0    M        0.0
# 1   101     Osaka        1989    Akiko  43.0     30.0    F        1.0
# 2   102     Kyoto        1992     Yuki  33.0     20.0    F        2.0
# 3   103  Hokkaido        1997   Satoru   NaN      NaN  NaN        NaN
# 4   104     Tokyo        1982   Steeve   NaN      NaN  NaN        NaN
# 5   106     Tokyo        1991   Mituru   NaN      NaN  NaN        NaN
# 6   108     Osaka        1988      Aoi   NaN      NaN  NaN        NaN
# 7   110     Kyoto        1990    Tarou   NaN      NaN  NaN        NaN
# 8   111  Hokkaido        1995   Suguru   NaN      NaN  NaN        NaN
# 9   113     Tokyo        1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
pd.merge(df1,df2,how='right')
# Out:
#     id   city  birth_year     name  math  english sex  index_num
# 0  100  Tokyo      1990.0  Hiroshi    50       90   M          0
# 1  101  Osaka      1989.0    Akiko    43       30   F          1
# 2  102  Kyoto      1992.0     Yuki    33       20   F          2
# 3  105    NaN         NaN      NaN    76       50   M          3
# 4  107    NaN         NaN      NaN    98       30   M          4

# %%
pd.merge(df1,df2,how='outer')
# Out:
#       id      city  birth_year     name  math  english  sex  index_num
# 0    113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN
# 1    100     Tokyo      1990.0  Hiroshi  50.0     90.0    M        0.0
# 2    101     Osaka      1989.0    Akiko  43.0     30.0    F        1.0
# 3    102     Kyoto      1992.0     Yuki  33.0     20.0    F        2.0
# 4    103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 5    104     Tokyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 6    105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 7    106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 8    107       NaN         NaN      NaN  98.0     30.0    M        4.0
# 9    108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 10   110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 11   111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN

# %%
data3 = {
    'id': ['117', '118', '119', '120', '125'],
    'city': ['Chiba', 'Kanagawa', 'Tokyo', 'Fukuoka', 'Okinawa'],
    'birth_year': [1990, 1989, 1992, 1997, 1982],
    'name': ['Suguru', 'Kouichi', 'Satochi', 'Yukie', 'Akari']
}
df3 = DataFrame(data3)
df3
# Out:
#     id      city  birth_year     name
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satochi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
df1
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo

# %%
pd.concat([df1,df3])
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo
# 0   117     Chiba        1990   Suguru
# 1   118  Kanagawa        1989  Kouichi
# 2   119     Tokyo        1992  Satochi
# 3   120   Fukuoka        1997    Yukie
# 4   125   Okinawa        1982    Akari

# %%
pd.concat([df1,df3],ignore_index=True)
# Out:
#       id      city  birth_year     name
# 0    100     Tokyo        1990  Hiroshi
# 1    101     Osaka        1989    Akiko
# 2    102     Kyoto        1992     Yuki
# 3    103  Hokkaido        1997   Satoru
# 4    104     Tokyo        1982   Steeve
# 5    106     Tokyo        1991   Mituru
# 6    108     Osaka        1988      Aoi
# 7    110     Kyoto        1990    Tarou
# 8    111  Hokkaido        1995   Suguru
# 9    113     Tokyo        1981   Mitsuo
# 10   117     Chiba        1990   Suguru
# 11   118  Kanagawa        1989  Kouichi
# 12   119     Tokyo        1992  Satochi
# 13   120   Fukuoka        1997    Yukie
# 14   125   Okinawa        1982    Akari

# %%
pd.concat([df1,df2])
# Out:
#      id      city  birth_year     name  math  english  sex  index_num
# 0   100     Tokyo      1990.0  Hiroshi   NaN      NaN  NaN        NaN
# 1   101     Osaka      1989.0    Akiko   NaN      NaN  NaN        NaN
# 2   102     Kyoto      1992.0     Yuki   NaN      NaN  NaN        NaN
# 3   103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 4   104     Tokyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 5   106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 6   108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 7   110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 8   111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN
# 9   113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN
# 0   100       NaN         NaN      NaN  50.0     90.0    M        0.0
# 1   101       NaN         NaN      NaN  43.0     30.0    F        1.0
# 2   102       NaN         NaN      NaN  33.0     20.0    F        2.0
# 3   105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 4   107       NaN         NaN      NaN  98.0     30.0    M        4.0

# %%
pd.concat([df1,df2],sort=True)
#カラム名を並べ替え
# Out:
#    birth_year      city  english    id  index_num  math     name  sex
# 0      1990.0     Tokyo      NaN   100        NaN   NaN  Hiroshi  NaN
# 1      1989.0     Osaka      NaN   101        NaN   NaN    Akiko  NaN
# 2      1992.0     Kyoto      NaN   102        NaN   NaN     Yuki  NaN
# 3      1997.0  Hokkaido      NaN   103        NaN   NaN   Satoru  NaN
# 4      1982.0     Tokyo      NaN   104        NaN   NaN   Steeve  NaN
# 5      1991.0     Tokyo      NaN   106        NaN   NaN   Mituru  NaN
# 6      1988.0     Osaka      NaN   108        NaN   NaN      Aoi  NaN
# 7      1990.0     Kyoto      NaN   110        NaN   NaN    Tarou  NaN
# 8      1995.0  Hokkaido      NaN   111        NaN   NaN   Suguru  NaN
# 9      1981.0     Tokyo      NaN   113        NaN   NaN   Mitsuo  NaN
# 0         NaN       NaN     90.0   100        0.0  50.0      NaN    M
# 1         NaN       NaN     30.0   101        1.0  43.0      NaN    F
# 2         NaN       NaN     20.0   102        2.0  33.0      NaN    F
# 3         NaN       NaN     50.0   105        3.0  76.0      NaN    M
# 4         NaN       NaN     30.0   107        4.0  98.0      NaN    M

# %%
pd.concat([df1,df2],axis=1)
# Out:
#      id      city  birth_year     name   id  math  english  sex  index_num
# 0   100     Tokyo        1990  Hiroshi  100  50.0     90.0    M        0.0
# 1   101     Osaka        1989    Akiko  101  43.0     30.0    F        1.0
# 2   102     Kyoto        1992     Yuki  102  33.0     20.0    F        2.0
# 3   103  Hokkaido        1997   Satoru  105  76.0     50.0    M        3.0
# 4   104     Tokyo        1982   Steeve  107  98.0     30.0    M        4.0
# 5   106     Tokyo        1991   Mituru  NaN   NaN      NaN  NaN        NaN
# 6   108     Osaka        1988      Aoi  NaN   NaN      NaN  NaN        NaN
# 7   110     Kyoto        1990    Tarou  NaN   NaN      NaN  NaN        NaN
# 8   111  Hokkaido        1995   Suguru  NaN   NaN      NaN  NaN        NaN
# 9   113     Tokyo        1981   Mitsuo  NaN   NaN      NaN  NaN        NaN

# %%
df[df['City']=='Tokyo']
# Out:
#     ID   City  Birth_year     Name  Score
# 0  100  Tokyo        1990  Hiroshi      0
# 4  104  Tokyo        1982    Steve     40

# %%
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        1990  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
df.drop(['Birth_year'],axis=1)
# Out:
#     ID      City     Name  Score
# 0  100     Tokyo  Hiroshi      0
# 1  101     Osaka    Akiko     10
# 2  102     Kyoto     Yuki     20
# 3  103  Hokkaido   Satoru     30
# 4  104     Tokyo    Steve     40

# %%
data = {'ID':['100','101','102','103','104'],
            'City':['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
            'Birth_year':[1990,1989,1992,1997,1982],
            'Name':['Hiroshi','Akiko','Yuki','Satoru','Steve']}

df = DataFrame(data)

print(df)
# Out:
#     ID      City  Birth_year     Name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982    Steve

# %%
df['Score']=np.arange(5)*10

# %%
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        1990  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
df.drop(['Birth_year'],axis=1)
# Out:
#     ID      City     Name  Score
# 0  100     Tokyo  Hiroshi      0
# 1  101     Osaka    Akiko     10
# 2  102     Kyoto     Yuki     20
# 3  103  Hokkaido   Satoru     30
# 4  104     Tokyo    Steve     40

# %%
#.reset_index()でインデックスを連続に、
df.drop(index=[0,2]).reset_index()
# Out:
#    index   ID      City  Birth_year    Name  Score
# 0      1  101     Osaka        1989   Akiko     10
# 1      3  103  Hokkaido        1997  Satoru     30
# 2      4  104     Tokyo        1982   Steve     40

# %%
hier_df = DataFrame(
    np.arange(9).reshape(3,3),
    index = [
        ['a','b','c'],
        [1,2,2]
    ],
    columns = [
        ['Osaka','Tokyo','Osaka'],
        ['Blue','Red','Red']
    ]
)

hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
# b 2     3     4     5
# c 2     6     7     8

# %%
hier_df.index.names = ['key1','key2']
hier_df.columns.names=['city','color']
hier_df
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
# b    2        3     4     5
# c    2        6     7     8

# %%
hier_df['Osaka']
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    2
# b    2        3    5
# c    2        6    8

# %%
hier_df.groupby(level='key2' , axis=0).sum()
# Out:
# /var/folders/3x/8k7v_11s16vgs7lky0_9jwrm0000gn/T/ipykernel_15677/1178919761.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   hier_df.groupby(level='key2' , axis=0).sum()
# city  Osaka Tokyo Osaka
# color  Blue   Red   Red
# key2
# 1         0     1     2
# 2         9    11    13

# %%
hier_df.groupby(level='color',axis=1).mean()
# Out:
# /var/folders/3x/8k7v_11s16vgs7lky0_9jwrm0000gn/T/ipykernel_15677/1287237984.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   hier_df.groupby(level='color',axis=1).mean()
# color      Blue  Red
# key1 key2
# a    1      0.0  1.5
# b    2      3.0  4.5
# c    2      6.0  7.5

# %%
#変数.drop([インデックス])
hier_df.drop(labels=[1],level=1)
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# b 2     3     4     5
# c 2     6     7     8

# %%
# hier_dfを用意
hier_df= DataFrame(
    np.arange(9).reshape((3, 3)),
    index = [
        ['a', 'a', 'b'],
        [1, 2, 2]
    ],
    columns = [
        ['Osaka', 'Tokyo', 'Osaka'],
        ['Blue','Red','Red']
    ]
)
hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
hier_df.stack()
# Out:
# /var/folders/3x/8k7v_11s16vgs7lky0_9jwrm0000gn/T/ipykernel_15677/4260390342.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   hier_df.stack()
#           Osaka  Tokyo
# a 1 Blue      0    NaN
#     Red       2    1.0
#   2 Blue      3    NaN
#     Red       5    4.0
# b 2 Blue      6    NaN
#     Red       8    7.0

# %%
hier_df.stack().unstack()
# Out:
# /var/folders/3x/8k7v_11s16vgs7lky0_9jwrm0000gn/T/ipykernel_15677/843577800.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   hier_df.stack().unstack()
#     Osaka     Tokyo
#      Blue Red  Blue  Red
# a 1     0   2   NaN  1.0
#   2     3   5   NaN  4.0
# b 2     6   8   NaN  7.0

# %%
#　重複があるデータ
dupli_data = DataFrame({
        'col1': [1, 1, 2, 3, 4, 4, 6, 6],
        'col2': ['a', 'b', 'b', 'b', 'c', 'c', 'b', 'b']
})
print('・元のデータ')
dupli_data
# Out:
# ・元のデータ
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 5     4    c
# 6     6    b
# 7     6    b

# %%
dupli_data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
dupli_data.drop_duplicates()
# Out:
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 6     6    b

# %%
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        1990  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
#マッピング処理：参照テーブルからキーに対応するデータを持ってくる
city_map ={
    'Tokyo':'Kanto',
    'Hokkaido':'Hokkaido',
    'Osaka':'Kansai',
    'Kyoto':'Kansai'
}
city_map
# Out:
# {'Tokyo': 'Kanto',
#  'Hokkaido': 'Hokkaido',
#  'Osaka': 'Kansai',
#  'Kyoto': 'Kansai'}

# %%
df1['region']=df1['city'].map(city_map)
df1
# Out:
#      id      city  birth_year     name    region
# 0   100     Tokyo        1990  Hiroshi     Kanto
# 1   101     Osaka        1989    Akiko    Kansai
# 2   102     Kyoto        1992     Yuki    Kansai
# 3   103  Hokkaido        1997   Satoru  Hokkaido
# 4   104     Tokyo        1982   Steeve     Kanto
# 5   106     Tokyo        1991   Mituru     Kanto
# 6   108     Osaka        1988      Aoi    Kansai
# 7   110     Kyoto        1990    Tarou    Kansai
# 8   111  Hokkaido        1995   Suguru  Hokkaido
# 9   113     Tokyo        1981   Mitsuo     Kanto

# %%
df1['up_two_num'] = df1['birth_year'].map(lambda x : str(x)[0:3])
df1
# Out:
#      id      city  birth_year     name    region up_two_num
# 0   100     Tokyo        1990  Hiroshi     Kanto        199
# 1   101     Osaka        1989    Akiko    Kansai        198
# 2   102     Kyoto        1992     Yuki    Kansai        199
# 3   103  Hokkaido        1997   Satoru  Hokkaido        199
# 4   104     Tokyo        1982   Steeve     Kanto        198
# 5   106     Tokyo        1991   Mituru     Kanto        199
# 6   108     Osaka        1988      Aoi    Kansai        198
# 7   110     Kyoto        1990    Tarou    Kansai        199
# 8   111  Hokkaido        1995   Suguru  Hokkaido        199
# 9   113     Tokyo        1981   Mitsuo     Kanto        198

# %%
str(df['Birth_year'])[0:3]
# Out:
# '0  '

# %%
df
# Out:
#     ID      City  Birth_year     Name  Score
# 0  100     Tokyo        1990  Hiroshi      0
# 1  101     Osaka        1989    Akiko     10
# 2  102     Kyoto        1992     Yuki     20
# 3  103  Hokkaido        1997   Satoru     30
# 4  104     Tokyo        1982    Steve     40

# %%
df['up_to_num']=df['City'].map(lambda x:str(x)[0:3])
df
# Out:
#     ID      City  Birth_year     Name  Score up_to_num
# 0  100     Tokyo        1990  Hiroshi      0       Tok
# 1  101     Osaka        1989    Akiko     10       Osa
# 2  102     Kyoto        1992     Yuki     20       Kyo
# 3  103  Hokkaido        1997   Satoru     30       Hok
# 4  104     Tokyo        1982    Steve     40       Tok

# %%
df1
# Out:
#      id      city  birth_year     name    region up_two_num
# 0   100     Tokyo        1990  Hiroshi     Kanto        199
# 1   101     Osaka        1989    Akiko    Kansai        198
# 2   102     Kyoto        1992     Yuki    Kansai        199
# 3   103  Hokkaido        1997   Satoru  Hokkaido        199
# 4   104     Tokyo        1982   Steeve     Kanto        198
# 5   106     Tokyo        1991   Mituru     Kanto        199
# 6   108     Osaka        1988      Aoi    Kansai        198
# 7   110     Kyoto        1990    Tarou    Kansai        199
# 8   111  Hokkaido        1995   Suguru  Hokkaido        199
# 9   113     Tokyo        1981   Mitsuo     Kanto        198

# %%
birth_year_bins = [1980, 1985, 1990, 1995, 2000]

birth_year_cut_data = pd.cut(df1['birth_year'], birth_year_bins)
birth_year_cut_data
#(1985, 1990]:1985より上、1990まで
# Out:
# 0    (1985, 1990]
# 1    (1985, 1990]
# 2    (1990, 1995]
# 3    (1995, 2000]
# 4    (1980, 1985]
# 5    (1990, 1995]
# 6    (1985, 1990]
# 7    (1985, 1990]
# 8    (1990, 1995]
# 9    (1980, 1985]
# Name: birth_year, dtype: category
# Categories (4, interval[int64, right]): [(1980, 1985] < (1985, 1990] < (1990, 1995] < (1995, 2000]]

# %%
pd.value_counts(birth_year_cut_data)
# Out:
# /var/folders/3x/8k7v_11s16vgs7lky0_9jwrm0000gn/T/ipykernel_15677/1731862176.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(birth_year_cut_data)
# birth_year
# (1985, 1990]    4
# (1990, 1995]    3
# (1980, 1985]    2
# (1995, 2000]    1
# Name: count, dtype: int64

# %%
group_names = ['ear]
