# %%
pip install biopython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
array = input('配列を入力してください： ')
# seed_pdb(array)

# %%
import numpy as np
from Bio.PDB import PDBParser
import subprocess

# %%
def seed_pdb(array):
