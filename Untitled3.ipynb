# %%
file_name = '/Users/teraimao/experiment/work/13_14_15_K,N,S,Y,F_work/analysis/ana_gbsw_in/solv_free_ener/all_output.dat'

# %%
with open(file_name,'r')as f:
    lines = f.readlines()

values =[float(line.split()[1]) for line in lines if len(line.split()) >=2 ]
average = sum(values) / len(values)

# %%
sub_set = values[:500]

average = sum(sub_set)/len(sub_set)
print(average)
# Out:
# -136.39963014

# %% [markdown]
# 0~50 ps の平均：-134.57979139999995
# 0~100 psの平均：-135.43391649999998
# 0~500 psの平均：-136.39963014
